# %% [markdown]
# # Assignment on Map-Reduce

# %% [markdown]
# In the following questions, you will solve real problems with the techniques you have learned before. You will be working with data of **google play dataset** which includes the following datasets:
# 1. googleplaystore
# 2. googleplaystore review
#
# *You can find the data files on the archive have attached to this exercise.*

# %% [markdown]
# **T** (10pts) Number of applications according to the version of Android(output must be sorted)
#
#
# > result:
# `<version, count>`

# %%
# %%writefile nikoo_big_data_hw1.py

from mrjob.job import MRJob,MRStep

class VersionCount(MRJob):
     
    def mapper(self,_, lines):
        for line in lines.split('\n'):
            item = line.split('∑') 
            if item[-1] != "Android Ver":
                yield item[-1],1
            
    def reducer(self, item, counts):
        yield item, sum(counts)
      
        
if __name__ == '__main__':
    VersionCount.run()
# Out:
# Overwriting nikoo_big_data_hw1.py

# %%
# !python nikoo_big_data_hw1.py googleplaystore.txt -q
# Out:
# "1.0 and up"	2
# "1.5 and up"	20
# "1.6 and up"	116
# "2.0 and up"	32
# "2.0.1 and up"	7
# "2.1 and up"	134
# "2.2 - 7.1.1"	1
# "2.2 and up"	244
# "2.3 and up"	652
# "2.3.3 and up"	281
# "3.0 and up"	241
# "3.1 and up"	10
# "3.2 and up"	36
# "4.0 and up"	1375
# "4.0.3 - 7.1.1"	2
# "4.0.3 and up"	1501
# "4.1 - 7.1.1"	1
# "4.1 and up"	2451
# "4.2 and up"	394
# "4.3 and up"	243
# "4.4 and up"	980
# "4.4W and up"	12
# "5.0 - 6.0"	1
# "5.0 - 7.1.1"	1
# "5.0 - 8.0"	2
# "5.0 and up"	600
# "5.1 and up"	24
# "6.0 and up"	60
# "7.0 - 7.1.1"	1
# "7.0 and up"	42
# "7.1 and up"	3
# "8.0 and up"	6
# "NaN"	2
# "Varies with device"	1362

# %% [markdown]
# **T** (10pts) K of the best applications in every category(K should be specified by user)
#
#
# > result:
# `<appname,{other fields} >`

# %%
# %%writefile nikoo_big_data_hw1.py

from mrjob.job import MRJob,MRStep
#from mrjob.compat import get_jobconf_value
import pandas as pd
from operator import itemgetter

class BestApplications(MRJob):
    k = 3
    def mapper(self,_, lines):
        apps = []        
        for line in lines.split('\n'):
            app = line.split('∑')
            if app[2] == "NaN":
                app[2] = "-1"
            if app[1] != "Category":
                yield app[1],app

            
    def reducer(self, category, apps):        
        sorted_list = sorted(apps, key=itemgetter(2), reverse=True)
        for app in sorted_list[0:self.k]:
            yield app[0],app

    
if __name__ == '__main__':
    BestApplications.run()
# Out:
# Overwriting nikoo_big_data_hw1.py

# %%
# !python nikoo_big_data_hw1.py googleplaystore.txt -q
# Out:
# "Spring flowers theme couleurs d t space"	["Spring flowers theme couleurs d t space","ART_AND_DESIGN","5","1","2.9M","100+","Free","0","Everyone","Art & Design","18-Apr-18","1.0.2","4.0 and up"]
# "Harley Quinn wallpapers HD"	["Harley Quinn wallpapers HD","ART_AND_DESIGN","4.8","192","6.0M","10,000+","Free","0","Everyone","Art & Design","25-Apr-18","1.5","3.0 and up"]
# "Cardi B Wallpaper"	["Cardi B Wallpaper","ART_AND_DESIGN","4.8","253","3.7M","50,000+","Free","0","Everyone","Art & Design","1-Nov-17","1.0.0","4.0 and up"]
# "Tickets SDA 2018 and Exam from the State Traffic Safety Inspectorate with Drom.ru"	["Tickets SDA 2018 and Exam from the State Traffic Safety Inspectorate with Drom.ru","AUTO_AND_VEHICLES","4.9","10479","33M","100,000+","Free","0","Everyone","Auto & Vehicles","18-Jul-18","1.7.1","4.0 and up"]
# "CDL Practice Test 2018 Edition"	["CDL Practice Test 2018 Edition","AUTO_AND_VEHICLES","4.9","7774","17M","100,000+","Free","0","Everyone","Auto & Vehicles","3-Jul-18","1.7","4.2 and up"]
# "DMV Permit Practice Test 2018 Edition"	["DMV Permit Practice Test 2018 Edition","AUTO_AND_VEHICLES","4.9","6090","27M","100,000+","Free","0","Everyone","Auto & Vehicles","3-Jul-18","1.7","4.2 and up"]
# "ipsy: Makeup, Beauty, and Tips"	["ipsy: Makeup, Beauty, and Tips","BEAUTY","4.9","49790","14M","1,000,000+","Free","0","Everyone","Beauty","9-Nov-17","2.3.0","4.1 and up"]
# "Prom MakeUp Tutorial"	["Prom MakeUp Tutorial","BEAUTY","4.8","104","12M","10,000+","Free","0","Everyone","Beauty","26-Jun-18","1.3","4.0.3 and up"]
# "Hush - Beauty for Everyone"	["Hush - Beauty for Everyone","BEAUTY","4.7","18900","17M","500,000+","Free","0","Everyone","Beauty","2-Aug-18","6.10.1","5.0 and up"]
# "R Programing Offline Tutorial"	["R Programing Offline Tutorial","BOOKS_AND_REFERENCE","5","4","3.9M","1,000+","Free","0","Everyone","Books & Reference","15-Mar-18","1.0.0","4.1 and up"]
# "Hey AJ! It's Saturday!"	["Hey AJ! It's Saturday!","BOOKS_AND_REFERENCE","5","12","50M","100+","Paid","\"$3.99 \"","Everyone","Books & Reference","13-Jun-16","1.0.0","2.2 and up"]
# "Tozer Devotional -Series 1"	["Tozer Devotional -Series 1","BOOKS_AND_REFERENCE","5","5","4.3M","1,000+","Free","0","Everyone","Books & Reference","8-Oct-16","1","2.3 and up"]
# "Ag Valley Cooperative"	["Ag Valley Cooperative","BUSINESS","5","6","74M","500+","Free","0","Everyone","Business","26-Jun-17","2.3","4.0 and up"]
# "Jobs in Canada - Emplois au Canada"	["Jobs in Canada - Emplois au Canada","BUSINESS","5","2","14M","1,000+","Free","0","Teen","Business","5-Aug-18","1.1","4.2 and up"]
# "Propel BI APP"	["Propel BI APP","BUSINESS","5","3","23M","100+","Free","0","Everyone","Business","24-Jul-18","1.39","4.4 and up"]
# "Hojiboy Tojiboyev Life Hacks"	["Hojiboy Tojiboyev Life Hacks","COMICS","5","15","37M","1,000+","Free","0","Everyone","Comics","26-Jun-18","2","4.0.3 and up"]
# "Superheroes, Marvel, DC, Comics, TV, Movies News"	["Superheroes, Marvel, DC, Comics, TV, Movies News","COMICS","5","34","12M","5,000+","Free","0","Everyone","Comics","31-Jul-18","1.0.5","5.0 and up"]
# "Unicorn Pokez - Color By Number"	["Unicorn Pokez - Color By Number","COMICS","4.8","516","12M","50,000+","Free","0","Everyone","Comics;Creativity","3-Aug-18","1.0.6","4.4 and up"]
# "BS-Mobile"	["BS-Mobile","COMMUNICATION","5","1","683k","50+","Free","0","Everyone","Communication","3-Sep-15","0.1","2.3 and up"]
# "BV"	["BV","COMMUNICATION","5","3","1.6M","100+","Free","0","Everyone","Communication","4-Aug-16","1,01","3.0 and up"]
# "Cb browser"	["Cb browser","COMMUNICATION","5","5","3.7M","50+","Free","0","Everyone","Communication","2-Apr-18","1","4.0 and up"]
# "American Girls Mobile Numbers"	["American Girls Mobile Numbers","DATING","5","5","4.4M","1,000+","Free","0","Mature 17+","Dating","17-Jul-18","3","4.0.3 and up"]
# "Awake Dating"	["Awake Dating","DATING","5","2","70M","100+","Free","0","Mature 17+","Dating","24-Jul-18","2.2.9","4.4 and up"]
# "Spine- The dating app"	["Spine- The dating app","DATING","5","5","9.3M","500+","Free","0","Teen","Dating","14-Jul-18","4","4.0.3 and up"]
# "Learn Japanese, Korean, Chinese Offline & Free"	["Learn Japanese, Korean, Chinese Offline & Free","EDUCATION","4.9","133136","26M","1,000,000+","Free","0","Everyone","Education;Education","20-Jul-18","2.16.11.10","4.2 and up"]
# "Sago Mini Hat Maker"	["Sago Mini Hat Maker","EDUCATION","4.9","11","63M","1,000+","Paid","\"$3.99 \"","Everyone","Education;Pretend Play","24-Jul-17","1","4.0.3 and up"]
# "English Grammar Test"	["English Grammar Test","EDUCATION","4.8","4075","5.1M","500,000+","Free","0","Everyone","Education","22-Jun-18","2.1.8","4.0.3 and up"]
# "_\ufffd\u04f4 Football Wallpapers 4K | Full HD Backgrounds _\ufffd\ufffd\ufffd"	["_\ufffd\u04f4 Football Wallpapers 4K | Full HD Backgrounds _\ufffd\ufffd\ufffd","ENTERTAINMENT","4.7","11661","4.0M","1,000,000+","Free","0","Everyone","Entertainment","14-Jul-18","1.1.3.2","4.0.3 and up"]
# "Motorola Spotlight Player\ufffd\ufffd"	["Motorola Spotlight Player\ufffd\ufffd","ENTERTAINMENT","4.6","22508","3.3M","10,000,000+","Free","0","Everyone","Entertainment","16-Jul-15","v1.8b22p13","4.2 and up"]
# "Twitch: Livestream Multiplayer Games & Esports"	["Twitch: Livestream Multiplayer Games & Esports","ENTERTAINMENT","4.6","2133296","Varies with device","50,000,000+","Free","0","Teen","Entertainment","31-Jul-18","Varies with device","Varies with device"]
# "SUMMER SONIC app"	["SUMMER SONIC app","EVENTS","5","4","61M","500+","Free","0","Everyone","Events","24-Jul-18","1","4.4 and up"]
# "Prosperity"	["Prosperity","EVENTS","5","16","2.3M","100+","Free","0","Everyone","Events","9-Jul-18","1.14","2.0 and up"]
# "Mindvalley U Tallinn 2018"	["Mindvalley U Tallinn 2018","EVENTS","5","1","21M","100+","Free","0","Everyone","Events","3-Jul-18","1.0.5","4.4 and up"]
# "Hey AJ! It's Bedtime!"	["Hey AJ! It's Bedtime!","FAMILY","5","1","63M","10+","Paid","\"$4.99 \"","Everyone","Education","4-Apr-18","1.0.59","2.3 and up"]
# "AJ Rafael Music Lessons"	["AJ Rafael Music Lessons","FAMILY","5","1","8.2M","10+","Free","0","Everyone","Entertainment","29-Nov-17","1.2.1","4.1 and up"]
# "AP\ufffd Guide"	["AP\ufffd Guide","FAMILY","5","3","2.1M","1,000+","Free","0","Everyone","Education","31-Jul-17","1.3","4.0.3 and up"]
# "BI APP"	["BI APP","FINANCE","5","2","2.7M","100+","Free","0","Everyone","Finance","19-Feb-16","1.8","4.0 and up"]
# "BK Gold App"	["BK Gold App","FINANCE","5","4","11M","50+","Free","0","Everyone","Finance","25-May-18","1.0.0","4.4 and up"]
# "BxPort - Bitcoin Bx (Thailand)"	["BxPort - Bitcoin Bx (Thailand)","FINANCE","5","4","4.1M","50+","Free","0","Everyone","Finance","14-Jul-18","1.0.4","4.2 and up"]
# "Food-Aw - Order Food Online in Aruba"	["Food-Aw - Order Food Online in Aruba","FOOD_AND_DRINK","5","1","24M","100+","Free","0","Everyone","Food & Drink","5-Apr-18","10","4.1 and up"]
# "Bar-B-Q Rib House"	["Bar-B-Q Rib House","FOOD_AND_DRINK","5","2","33M","50+","Free","0","Everyone","Food & Drink","8-Mar-18","0.8","2.3.3 and up"]
# "SarashpazPapion (Cooking with Chef Bowls)"	["SarashpazPapion (Cooking with Chef Bowls)","FOOD_AND_DRINK","4.8","1250","13M","50,000+","Free","0","Everyone","Food & Drink","28-Jul-18","3.2.7","4.1 and up"]
# "Axe Champs! Wars"	["Axe Champs! Wars","GAME","5","8","25M","50+","Free","0","Everyone","Arcade","26-Jun-18","1.1","4.1 and up"]
# "Flippy Axe : Flip The Knife & Axe Simulator"	["Flippy Axe : Flip The Knife & Axe Simulator","GAME","5","7","15M","100+","Free","0","Everyone","Arcade","27-Sep-17","1.1","4.2 and up"]
# "Ra Ga Ba"	["Ra Ga Ba","GAME","5","2","20M","1+","Paid","\"$1.49 \"","Everyone","Arcade","8-Feb-17","1.0.4","2.3 and up"]
# "BM Physiotherapy Clinic"	["BM Physiotherapy Clinic","HEALTH_AND_FITNESS","5","3","9.3M","100+","Free","0","Everyone","Health & Fitness","9-Oct-17","0.0.1","4.1 and up"]
# "MI-BP"	["MI-BP","HEALTH_AND_FITNESS","5","1","12M","50+","Free","0","Everyone","Health & Fitness","9-Apr-18","1.0.8.506","5.0 and up"]
# "Bacterial vaginosis Treatment - Sexual disease"	["Bacterial vaginosis Treatment - Sexual disease","HEALTH_AND_FITNESS","5","2","5.9M","500+","Free","0","Everyone","Health & Fitness","25-Jun-18","2","4.0.3 and up"]
# "Viva Decora - Decoration, Photos, Architecture, House"	["Viva Decora - Decoration, Photos, Architecture, House","HOUSE_AND_HOME","4.8","3167","7.5M","100,000+","Free","0","Everyone","House & Home","3-Aug-18","2.0.0","5.0 and up"]
# "DIY On A Budget"	["DIY On A Budget","HOUSE_AND_HOME","4.7","114","8.3M","10,000+","Free","0","Teen","House & Home","18-Feb-18","2.1","4.1 and up"]
# "Ruler"	["Ruler","HOUSE_AND_HOME","4.7","126","1.9M","10,000+","Free","0","Everyone","House & Home","21-Aug-17","1","4.0 and up"]
# "Eternal life"	["Eternal life","LIBRARIES_AND_DEMO","5","26","2.5M","1,000+","Free","0","Everyone","Libraries & Demo","24-May-18","1","1.6 and up"]
# "Nur t\ufffd\ufffdfsiri 1-ci cild"	["Nur t\ufffd\ufffdfsiri 1-ci cild","LIBRARIES_AND_DEMO","5","15","1.4M","1,000+","Free","0","Everyone","Libraries & Demo","27-Apr-17","1","1.6 and up"]
# "Call Recorder"	["Call Recorder","LIBRARIES_AND_DEMO","4.7","48","6.9M","1,000+","Free","0","Everyone","Libraries & Demo","25-May-18","1.7.2.10","4.0 and up"]
# "Tafsiir Quraan MP3 Af Soomaali Quraanka Kariimka"	["Tafsiir Quraan MP3 Af Soomaali Quraanka Kariimka","LIFESTYLE","5","7","3.4M","1,000+","Free","0","Everyone","Lifestyle","9-Jun-18","1.4","4.0 and up"]
# "Lakeside AG Moultrie"	["Lakeside AG Moultrie","LIFESTYLE","5","3","8.6M","50+","Free","0","Everyone","Lifestyle","23-May-17","1","4.1 and up"]
# "AJ Men's Grooming"	["AJ Men's Grooming","LIFESTYLE","5","2","22M","100+","Free","0","Everyone","Lifestyle","28-Aug-17","5","4.1 and up"]
# "Tour BD (Bahir Dar Map)"	["Tour BD (Bahir Dar Map)","MAPS_AND_NAVIGATION","4.9","49","3.9M","100+","Free","0","Everyone","Maps & Navigation","16-Oct-17","2","4.2 and up"]
# "BL Taxi"	["BL Taxi","MAPS_AND_NAVIGATION","4.9","124","3.4M","1,000+","Free","0","Everyone","Maps & Navigation","26-Mar-18","Varies with device","Varies with device"]
# "GPS Speedometer and Odometer"	["GPS Speedometer and Odometer","MAPS_AND_NAVIGATION","4.8","15865","3.3M","1,000,000+","Free","0","Everyone","Maps & Navigation","3-Aug-18","10","4.1 and up"]
# "Super Hearing Secret Voices Recorder PRO"	["Super Hearing Secret Voices Recorder PRO","MEDICAL","5","3","23M","100+","Paid","\"$2.99 \"","Everyone","Medical","20-Apr-18","1","4.1 and up"]
# "FHR 5-Tier 2.0"	["FHR 5-Tier 2.0","MEDICAL","5","2","1.2M","500+","Paid","\"$2.99 \"","Everyone","Medical","16-Dec-15","1","4.0 and up"]
# "Sway Medical"	["Sway Medical","MEDICAL","5","3","22M","100+","Free","0","Everyone","Medical","25-Jul-18","3.0.0","5.0 and up"]
# "AI Today : Artificial Intelligence News & AI 101"	["AI Today : Artificial Intelligence News & AI 101","NEWS_AND_MAGAZINES","5","43","2.3M","100+","Free","0","Everyone","News & Magazines","22-Jun-18","1","4.4 and up"]
# "BI News"	["BI News","NEWS_AND_MAGAZINES","5","22","25M","1,000+","Free","0","Everyone","News & Magazines","10-Jun-18","1.5.0","4.1 and up"]
# "Startupticker.ch News, Events"	["Startupticker.ch News, Events","NEWS_AND_MAGAZINES","5","4","10M","100+","Free","0","Everyone","News & Magazines","23-Jul-18","2.0.0","4.4 and up"]
# "DF Glue Board"	["DF Glue Board","PARENTING","5","1","27M","10+","Free","0","Everyone","Parenting","19-Jan-18","Glueboardv.6","4.2 and up"]
# "White Noise for Baby"	["White Noise for Baby","PARENTING","4.9","717","6.6M","100,000+","Free","0","Everyone","Parenting","30-Dec-17","1.6.0","4.1 and up"]
# "How do I take care of my child?"	["How do I take care of my child?","PARENTING","4.8","190","6.8M","100,000+","Free","0","Everyone","Parenting","24-Jun-18","1.5","4.0 and up"]
# "P-Home for KLWP"	["P-Home for KLWP","PERSONALIZATION","5","4","12M","100+","Paid","\"$0.99 \"","Everyone","Personalization","15-May-18","v2018.May.15.14","5.0 and up"]
# "Android P Style Icon Pack"	["Android P Style Icon Pack","PERSONALIZATION","5","1","60M","100+","Paid","\"$0.99 \"","Everyone","Personalization","16-Jun-18","1","4.1 and up"]
# "AJ Gray Dark Icon Pack"	["AJ Gray Dark Icon Pack","PERSONALIZATION","5","2","35M","10+","Paid","\"$0.99 \"","Everyone","Personalization","29-Apr-18","1.1","4.1 and up"]
# "AJ Cam"	["AJ Cam","PHOTOGRAPHY","5","44","2.8M","100+","Free","0","Everyone","Photography","23-Jan-18","1","4.1 and up"]
# "Selfie With Champion AJ Style"	["Selfie With Champion AJ Style","PHOTOGRAPHY","5","2","7.5M","500+","Free","0","Everyone","Photography","8-Jan-18","1","3.2 and up"]
# "CB VIDEO VISION"	["CB VIDEO VISION","PHOTOGRAPHY","5","13","2.6M","100+","Free","0","Everyone","Photography","12-Sep-17","0.0.2","4.1 and up"]
# "BV Mobile Apps"	["BV Mobile Apps","PRODUCTIVITY","5","3","4.8M","100+","Free","0","Everyone","Productivity","5-Jun-18","2","4.2 and up"]
# "CJ'S TIRE AND AUTO INC."	["CJ'S TIRE AND AUTO INC.","PRODUCTIVITY","5","5","11M","100+","Free","0","Everyone","Productivity","30-May-18","1.0.1","4.1 and up"]
# "iReadMe"	["iReadMe","PRODUCTIVITY","5","8","22M","100+","Free","0","Everyone","Productivity","6-Mar-18","1.5","4.4 and up"]
# "AJ RETAILS"	["AJ RETAILS","SHOPPING","5","9","169k","10+","Free","0","Everyone","Shopping","1-Jun-18","18060104","2.2 and up"]
# "A-Y Collection"	["A-Y Collection","SHOPPING","5","2","2.9M","100+","Free","0","Teen","Shopping","16-Feb-18","1.2","4.1 and up"]
# "BL Flowers Digital"	["BL Flowers Digital","SHOPPING","5","21","2.5M","100+","Free","0","Everyone","Shopping","31-Oct-17","1.6","4.2 and up"]
# "Eternal Light AG"	["Eternal Light AG","SOCIAL","5","30","13M","100+","Free","0","Teen","Social","19-May-18","1.04","4.0.3 and up"]
# "iCard BD Plus"	["iCard BD Plus","SOCIAL","5","2","2.4M","500+","Free","0","Everyone","Social","15-Jul-16","3.7.5","2.0 and up"]
# "Movement BE"	["Movement BE","SOCIAL","5","20","1.2M","100+","Free","0","Teen","Social","10-Nov-16","1.2","4.4 and up"]
# "CricQuick"	["CricQuick","SPORTS","5","17","1.5M","50+","Free","0","Everyone","Sports","8-Dec-17","1","4.0.3 and up"]
# "EC SPORTS"	["EC SPORTS","SPORTS","5","1","6.3M","10+","Free","0","Everyone","Sports","26-May-15","4.1.1","2.3.3 and up"]
# "FA Player Essentials"	["FA Player Essentials","SPORTS","5","7","68M","100+","Free","0","Everyone","Sports","23-Jul-18","1.6.0","4.0.3 and up"]
# "ADS-B Driver"	["ADS-B Driver","TOOLS","5","2","6.3M","100+","Paid","\"$1.99 \"","Everyone","Tools","15-May-18","1.19","4.4 and up"]
# "Easy Hotspot Ad Free"	["Easy Hotspot Ad Free","TOOLS","5","2","3.3M","10+","Paid","\"$0.99 \"","Everyone","Tools","26-Jul-18","1.05","4.0 and up"]
# "ReactNative BG Geolocation"	["ReactNative BG Geolocation","TOOLS","5","5","9.1M","1,000+","Free","0","Everyone","Tools","25-May-18","2.12.0","4.1 and up"]
# "BG Guide"	["BG Guide","TRAVEL_AND_LOCAL","5","3","2.4M","100+","Free","0","Everyone","Travel & Local","28-Nov-16","1.1","2.3.3 and up"]
# "CJ's Coffee Cafe"	["CJ's Coffee Cafe","TRAVEL_AND_LOCAL","5","6","2.4M","500+","Free","0","Everyone","Travel & Local","21-Aug-17","7.5.0","4.0.3 and up"]
# "Florida Beach Wallpapers HD"	["Florida Beach Wallpapers HD","TRAVEL_AND_LOCAL","5","3","12M","100+","Free","0","Everyone","Travel & Local","30-Dec-15","1.8.1","4.1 and up"]
# "AK Lodi Films"	["AK Lodi Films","VIDEO_PLAYERS","4.9","23","2.1M","100+","Free","0","Everyone","Video Players & Editors","11-Aug-15","1.1","4.0 and up"]
# "Video Player All Format"	["Video Player All Format","VIDEO_PLAYERS","4.8","259003","Varies with device","10,000,000+","Free","0","Everyone","Video Players & Editors","3-Aug-18","Varies with device","4.3 and up"]
# "DU Recorder \ufffd\ufffd\ufffd Screen Recorder, Video Editor, Live"	["DU Recorder \ufffd\ufffd\ufffd Screen Recorder, Video Editor, Live","VIDEO_PLAYERS","4.8","2588730","9.7M","50,000,000+","Free","0","Everyone","Video Players & Editors","30-Jul-18","1.7.1.3","5.0 and up"]
# "Weather forecast"	["Weather forecast","WEATHER","4.8","159455","10M","1,000,000+","Free","0","Everyone","Weather","8-May-18","1.11.93","4.4 and up"]
# "Live Weather Pro"	["Live Weather Pro","WEATHER","4.8","892","17M","10,000+","Free","0","Everyone","Weather","17-Jul-18","1.1","4.4 and up"]
# "Weather Live Pro"	["Weather Live Pro","WEATHER","4.8","17493","11M","100,000+","Paid","\"$4.49 \"","Everyone","Weather","20-Apr-18","1.3","4.4 and up"]

# %% [markdown]
# **T** (20pts) Number of applications in every category according to version of Android(output must be sorted on Count)
#
# > result:
# `<category, {count, version} >`

# %%
# %%writefile nikoo_big_data_hw1.py

from mrjob.job import MRJob,MRStep
#from mrjob.compat import get_jobconf_value
import pandas as pd
from operator import itemgetter

class NumOfApplication(MRJob):

    def steps(self):
        return [
            MRStep(mapper = self.mapper1,
                  reducer = self.reducer1),
            MRStep(reducer = self.reducer_sort)
        ]


    def mapper1(self,_, lines):
        apps = []        
        for line in lines.split('\n'):
            app = line.split('∑')
            yield (app[1], app[-1]), 1

            
    def reducer1(self, category_ver, count):        
        cat, ver = category_ver
        yield cat, (sum(count), ver)

   
    def reducer_sort(self, category, count_version):
        for count, ver in sorted(count_version, reverse=True):
            yield (category, (count, ver))
            
            

if __name__ == '__main__':
    NumOfApplication.run()
# Out:
# Overwriting nikoo_big_data_hw1.py

# %%
# !python nikoo_big_data_hw1.py googleplaystore.txt -q
# Out:
# "ART_AND_DESIGN"	[21,"4.1 and up"]
# "ART_AND_DESIGN"	[16,"4.0.3 and up"]
# "ART_AND_DESIGN"	[8,"2.3 and up"]
# "ART_AND_DESIGN"	[7,"4.0 and up"]
# "ART_AND_DESIGN"	[4,"4.2 and up"]
# "ART_AND_DESIGN"	[3,"4.4 and up"]
# "ART_AND_DESIGN"	[2,"Varies with device"]
# "ART_AND_DESIGN"	[2,"3.0 and up"]
# "ART_AND_DESIGN"	[1,"5.0 and up"]
# "ART_AND_DESIGN"	[1,"2.3.3 and up"]
# "AUTO_AND_VEHICLES"	[15,"4.1 and up"]
# "AUTO_AND_VEHICLES"	[15,"4.0 and up"]
# "AUTO_AND_VEHICLES"	[12,"4.0.3 and up"]
# "AUTO_AND_VEHICLES"	[8,"4.4 and up"]
# "AUTO_AND_VEHICLES"	[7,"Varies with device"]
# "AUTO_AND_VEHICLES"	[7,"4.2 and up"]
# "AUTO_AND_VEHICLES"	[6,"5.0 and up"]
# "AUTO_AND_VEHICLES"	[4,"6.0 and up"]
# "AUTO_AND_VEHICLES"	[3,"2.3.3 and up"]
# "AUTO_AND_VEHICLES"	[3,"2.3 and up"]
# "AUTO_AND_VEHICLES"	[2,"4.3 and up"]
# "AUTO_AND_VEHICLES"	[1,"4.4W and up"]
# "AUTO_AND_VEHICLES"	[1,"3.2 and up"]
# "AUTO_AND_VEHICLES"	[1,"2.2 and up"]
# "BEAUTY"	[18,"4.0.3 and up"]
# "BEAUTY"	[11,"4.0 and up"]
# "BEAUTY"	[9,"4.1 and up"]
# "BEAUTY"	[4,"5.0 and up"]
# "BEAUTY"	[3,"Varies with device"]
# "BEAUTY"	[3,"3.0 and up"]
# "BEAUTY"	[1,"4.4 and up"]
# "BEAUTY"	[1,"4.2 and up"]
# "BEAUTY"	[1,"2.3 and up"]
# "BEAUTY"	[1,"2.2 and up"]
# "BEAUTY"	[1,"1.6 and up"]
# "BOOKS_AND_REFERENCE"	[43,"4.0 and up"]
# "BOOKS_AND_REFERENCE"	[34,"4.1 and up"]
# "BOOKS_AND_REFERENCE"	[31,"Varies with device"]
# "BOOKS_AND_REFERENCE"	[30,"4.0.3 and up"]
# "BOOKS_AND_REFERENCE"	[18,"2.3 and up"]
# "BOOKS_AND_REFERENCE"	[17,"1.6 and up"]
# "BOOKS_AND_REFERENCE"	[12,"4.4 and up"]
# "BOOKS_AND_REFERENCE"	[12,"3.0 and up"]
# "BOOKS_AND_REFERENCE"	[10,"2.2 and up"]
# "BOOKS_AND_REFERENCE"	[6,"4.2 and up"]
# "BOOKS_AND_REFERENCE"	[6,"2.1 and up"]
# "BOOKS_AND_REFERENCE"	[5,"2.3.3 and up"]
# "BOOKS_AND_REFERENCE"	[2,"5.0 and up"]
# "BOOKS_AND_REFERENCE"	[1,"7.0 and up"]
# "BOOKS_AND_REFERENCE"	[1,"6.0 and up"]
# "BOOKS_AND_REFERENCE"	[1,"5.1 and up"]
# "BOOKS_AND_REFERENCE"	[1,"1.5 and up"]
# "BOOKS_AND_REFERENCE"	[1,"1.0 and up"]
# "BUSINESS"	[119,"4.1 and up"]
# "BUSINESS"	[75,"4.0 and up"]
# "BUSINESS"	[56,"4.0.3 and up"]
# "BUSINESS"	[45,"4.4 and up"]
# "BUSINESS"	[41,"Varies with device"]
# "BUSINESS"	[32,"5.0 and up"]
# "BUSINESS"	[17,"2.3.3 and up"]
# "BUSINESS"	[14,"4.2 and up"]
# "BUSINESS"	[12,"3.0 and up"]
# "BUSINESS"	[12,"2.2 and up"]
# "BUSINESS"	[10,"2.3 and up"]
# "BUSINESS"	[7,"4.3 and up"]
# "BUSINESS"	[4,"2.1 and up"]
# "BUSINESS"	[4,"1.6 and up"]
# "BUSINESS"	[3,"6.0 and up"]
# "BUSINESS"	[2,"5.1 and up"]
# "BUSINESS"	[2,"2.0 and up"]
# "BUSINESS"	[1,"7.0 and up"]
# "BUSINESS"	[1,"5.0 - 7.1.1"]
# "BUSINESS"	[1,"4.4W and up"]
# "BUSINESS"	[1,"3.2 and up"]
# "BUSINESS"	[1,"1.5 and up"]
# "COMICS"	[16,"4.0.3 and up"]
# "COMICS"	[10,"4.1 and up"]
# "COMICS"	[9,"Varies with device"]
# "COMICS"	[6,"4.0 and up"]
# "COMICS"	[5,"4.4 and up"]
# "COMICS"	[5,"2.3 and up"]
# "COMICS"	[3,"4.2 and up"]
# "COMICS"	[2,"5.0 and up"]
# "COMICS"	[1,"4.3 and up"]
# "COMICS"	[1,"3.0 and up"]
# "COMICS"	[1,"2.2 and up"]
# "COMMUNICATION"	[101,"Varies with device"]
# "COMMUNICATION"	[69,"4.1 and up"]
# "COMMUNICATION"	[46,"4.0 and up"]
# "COMMUNICATION"	[35,"4.0.3 and up"]
# "COMMUNICATION"	[25,"2.3 and up"]
# "COMMUNICATION"	[23,"4.4 and up"]
# "COMMUNICATION"	[18,"2.2 and up"]
# "COMMUNICATION"	[17,"5.0 and up"]
# "COMMUNICATION"	[9,"4.2 and up"]
# "COMMUNICATION"	[9,"3.0 and up"]
# "COMMUNICATION"	[7,"2.1 and up"]
# "COMMUNICATION"	[7,"1.6 and up"]
# "COMMUNICATION"	[6,"2.3.3 and up"]
# "COMMUNICATION"	[4,"4.3 and up"]
# "COMMUNICATION"	[4,"2.0 and up"]
# "COMMUNICATION"	[3,"6.0 and up"]
# "COMMUNICATION"	[2,"4.0.3 - 7.1.1"]
# "COMMUNICATION"	[1,"5.1 and up"]
# "COMMUNICATION"	[1,"3.2 and up"]
# "Category"	[1,"Android Ver"]
# "DATING"	[75,"4.0.3 and up"]
# "DATING"	[74,"4.1 and up"]
# "DATING"	[24,"4.0 and up"]
# "DATING"	[20,"4.4 and up"]
# "DATING"	[12,"Varies with device"]
# "DATING"	[12,"4.2 and up"]
# "DATING"	[10,"5.0 and up"]
# "DATING"	[4,"4.3 and up"]
# "DATING"	[2,"3.0 and up"]
# "DATING"	[1,"2.3 and up"]
# "EDUCATION"	[41,"Varies with device"]
# "EDUCATION"	[31,"4.1 and up"]
# "EDUCATION"	[25,"4.0 and up"]
# "EDUCATION"	[14,"5.0 and up"]
# "EDUCATION"	[13,"4.4 and up"]
# "EDUCATION"	[10,"2.3 and up"]
# "EDUCATION"	[9,"4.0.3 and up"]
# "EDUCATION"	[4,"4.2 and up"]
# "EDUCATION"	[2,"3.0 and up"]
# "EDUCATION"	[2,"2.3.3 and up"]
# "EDUCATION"	[2,"2.1 and up"]
# "EDUCATION"	[1,"3.2 and up"]
# "EDUCATION"	[1,"2.2 and up"]
# "EDUCATION"	[1,"1.6 and up"]
# "ENTERTAINMENT"	[52,"Varies with device"]
# "ENTERTAINMENT"	[42,"4.4 and up"]
# "ENTERTAINMENT"	[23,"4.1 and up"]
# "ENTERTAINMENT"	[10,"5.0 and up"]
# "ENTERTAINMENT"	[7,"4.0.3 and up"]
# "ENTERTAINMENT"	[5,"4.2 and up"]
# "ENTERTAINMENT"	[3,"6.0 and up"]
# "ENTERTAINMENT"	[2,"4.3 and up"]
# "ENTERTAINMENT"	[2,"4.0 and up"]
# "ENTERTAINMENT"	[2,"2.3.3 and up"]
# "ENTERTAINMENT"	[1,"2.3 and up"]
# "EVENTS"	[17,"4.1 and up"]
# "EVENTS"	[9,"4.2 and up"]
# "EVENTS"	[9,"4.0 and up"]
# "EVENTS"	[7,"Varies with device"]
# "EVENTS"	[6,"4.4 and up"]
# "EVENTS"	[4,"5.0 and up"]
# "EVENTS"	[4,"4.0.3 and up"]
# "EVENTS"	[2,"3.0 and up"]
# "EVENTS"	[2,"2.3.3 and up"]
# "EVENTS"	[1,"5.1 and up"]
# "EVENTS"	[1,"4.4W and up"]
# "EVENTS"	[1,"4.3 and up"]
# "EVENTS"	[1,"2.0 and up"]
# "FAMILY"	[516,"4.1 and up"]
# "FAMILY"	[307,"4.0.3 and up"]
# "FAMILY"	[290,"4.0 and up"]
# "FAMILY"	[188,"2.3 and up"]
# "FAMILY"	[150,"4.4 and up"]
# "FAMILY"	[83,"Varies with device"]
# "FAMILY"	[75,"2.3.3 and up"]
# "FAMILY"	[72,"4.2 and up"]
# "FAMILY"	[59,"2.2 and up"]
# "FAMILY"	[56,"3.0 and up"]
# "FAMILY"	[51,"5.0 and up"]
# "FAMILY"	[41,"4.3 and up"]
# "FAMILY"	[26,"2.1 and up"]
# "FAMILY"	[15,"1.6 and up"]
# "FAMILY"	[10,"7.0 and up"]
# "FAMILY"	[7,"3.2 and up"]
# "FAMILY"	[7,"2.0 and up"]
# "FAMILY"	[6,"5.1 and up"]
# "FAMILY"	[5,"2.0.1 and up"]
# "FAMILY"	[3,"6.0 and up"]
# "FAMILY"	[3,"3.1 and up"]
# "FAMILY"	[2,"1.5 and up"]
# "FINANCE"	[57,"4.1 and up"]
# "FINANCE"	[54,"5.0 and up"]
# "FINANCE"	[53,"Varies with device"]
# "FINANCE"	[51,"4.4 and up"]
# "FINANCE"	[47,"4.0 and up"]
# "FINANCE"	[37,"4.0.3 and up"]
# "FINANCE"	[28,"4.2 and up"]
# "FINANCE"	[8,"2.3 and up"]
# "FINANCE"	[7,"3.0 and up"]
# "FINANCE"	[5,"4.3 and up"]
# "FINANCE"	[5,"2.2 and up"]
# "FINANCE"	[4,"6.0 and up"]
# "FINANCE"	[3,"2.1 and up"]
# "FINANCE"	[2,"3.2 and up"]
# "FINANCE"	[2,"2.3.3 and up"]
# "FINANCE"	[1,"4.4W and up"]
# "FINANCE"	[1,"1.6 and up"]
# "FINANCE"	[1,"1.5 and up"]
# "FOOD_AND_DRINK"	[24,"Varies with device"]
# "FOOD_AND_DRINK"	[24,"4.1 and up"]
# "FOOD_AND_DRINK"	[22,"4.4 and up"]
# "FOOD_AND_DRINK"	[20,"5.0 and up"]
# "FOOD_AND_DRINK"	[15,"4.0.3 and up"]
# "FOOD_AND_DRINK"	[9,"4.0 and up"]
# "FOOD_AND_DRINK"	[4,"4.2 and up"]
# "FOOD_AND_DRINK"	[2,"6.0 and up"]
# "FOOD_AND_DRINK"	[2,"2.3.3 and up"]
# "FOOD_AND_DRINK"	[2,"2.3 and up"]
# "FOOD_AND_DRINK"	[1,"5.1 and up"]
# "FOOD_AND_DRINK"	[1,"4.3 and up"]
# "FOOD_AND_DRINK"	[1,"3.0 and up"]
# "GAME"	[339,"4.1 and up"]
# "GAME"	[177,"4.0.3 and up"]
# "GAME"	[171,"2.3 and up"]
# "GAME"	[128,"4.0 and up"]
# "GAME"	[60,"4.4 and up"]
# "GAME"	[56,"Varies with device"]
# "GAME"	[45,"2.3.3 and up"]
# "GAME"	[34,"3.0 and up"]
# "GAME"	[31,"4.2 and up"]
# "GAME"	[23,"4.3 and up"]
# "GAME"	[22,"5.0 and up"]
# "GAME"	[18,"2.1 and up"]
# "GAME"	[13,"2.2 and up"]
# "GAME"	[7,"6.0 and up"]
# "GAME"	[5,"7.0 and up"]
# "GAME"	[4,"2.0 and up"]
# "GAME"	[3,"1.5 and up"]
# "GAME"	[2,"1.6 and up"]
# "GAME"	[1,"5.1 and up"]
# "GAME"	[1,"4.4W and up"]
# "GAME"	[1,"3.2 and up"]
# "GAME"	[1,"3.1 and up"]
# "GAME"	[1,"2.2 - 7.1.1"]
# "GAME"	[1,"2.0.1 and up"]
# "HEALTH_AND_FITNESS"	[86,"4.1 and up"]
# "HEALTH_AND_FITNESS"	[73,"Varies with device"]
# "HEALTH_AND_FITNESS"	[37,"4.4 and up"]
# "HEALTH_AND_FITNESS"	[35,"4.0.3 and up"]
# "HEALTH_AND_FITNESS"	[32,"5.0 and up"]
# "HEALTH_AND_FITNESS"	[32,"4.0 and up"]
# "HEALTH_AND_FITNESS"	[11,"4.2 and up"]
# "HEALTH_AND_FITNESS"	[9,"4.3 and up"]
# "HEALTH_AND_FITNESS"	[7,"2.3.3 and up"]
# "HEALTH_AND_FITNESS"	[6,"2.3 and up"]
# "HEALTH_AND_FITNESS"	[4,"3.0 and up"]
# "HEALTH_AND_FITNESS"	[3,"2.2 and up"]
# "HEALTH_AND_FITNESS"	[2,"1.6 and up"]
# "HEALTH_AND_FITNESS"	[1,"8.0 and up"]
# "HEALTH_AND_FITNESS"	[1,"7.0 and up"]
# "HEALTH_AND_FITNESS"	[1,"2.1 and up"]
# "HEALTH_AND_FITNESS"	[1,"2.0 and up"]
# "HOUSE_AND_HOME"	[20,"Varies with device"]
# "HOUSE_AND_HOME"	[16,"4.0.3 and up"]
# "HOUSE_AND_HOME"	[11,"4.1 and up"]
# "HOUSE_AND_HOME"	[9,"5.0 and up"]
# "HOUSE_AND_HOME"	[9,"4.0 and up"]
# "HOUSE_AND_HOME"	[8,"4.4 and up"]
# "HOUSE_AND_HOME"	[7,"3.0 and up"]
# "HOUSE_AND_HOME"	[3,"2.3 and up"]
# "HOUSE_AND_HOME"	[2,"4.3 and up"]
# "HOUSE_AND_HOME"	[2,"4.2 and up"]
# "HOUSE_AND_HOME"	[1,"2.2 and up"]
# "LIBRARIES_AND_DEMO"	[26,"1.6 and up"]
# "LIBRARIES_AND_DEMO"	[15,"4.0.3 and up"]
# "LIBRARIES_AND_DEMO"	[12,"2.3 and up"]
# "LIBRARIES_AND_DEMO"	[8,"4.0 and up"]
# "LIBRARIES_AND_DEMO"	[4,"4.4 and up"]
# "LIBRARIES_AND_DEMO"	[4,"4.1 and up"]
# "LIBRARIES_AND_DEMO"	[3,"Varies with device"]
# "LIBRARIES_AND_DEMO"	[3,"5.0 and up"]
# "LIBRARIES_AND_DEMO"	[3,"2.2 and up"]
# "LIBRARIES_AND_DEMO"	[2,"1.5 and up"]
# "LIBRARIES_AND_DEMO"	[1,"7.1 and up"]
# "LIBRARIES_AND_DEMO"	[1,"4.2 and up"]
# "LIBRARIES_AND_DEMO"	[1,"3.2 and up"]
# "LIBRARIES_AND_DEMO"	[1,"3.0 and up"]
# "LIBRARIES_AND_DEMO"	[1,"2.3.3 and up"]
# "LIFESTYLE"	[100,"4.1 and up"]
# "LIFESTYLE"	[60,"4.0.3 and up"]
# "LIFESTYLE"	[57,"4.0 and up"]
# "LIFESTYLE"	[34,"4.4 and up"]
# "LIFESTYLE"	[30,"Varies with device"]
# "LIFESTYLE"	[24,"2.3 and up"]
# "LIFESTYLE"	[17,"4.3 and up"]
# "LIFESTYLE"	[12,"4.2 and up"]
# "LIFESTYLE"	[11,"5.0 and up"]
# "LIFESTYLE"	[11,"2.3.3 and up"]
# "LIFESTYLE"	[10,"2.2 and up"]
# "LIFESTYLE"	[5,"3.0 and up"]
# "LIFESTYLE"	[5,"2.1 and up"]
# "LIFESTYLE"	[2,"3.2 and up"]
# "LIFESTYLE"	[1,"7.0 and up"]
# "LIFESTYLE"	[1,"7.0 - 7.1.1"]
# "LIFESTYLE"	[1,"6.0 and up"]
# "LIFESTYLE"	[1,"1.6 and up"]
# "MAPS_AND_NAVIGATION"	[33,"4.1 and up"]
# "MAPS_AND_NAVIGATION"	[27,"Varies with device"]
# "MAPS_AND_NAVIGATION"	[24,"4.0 and up"]
# "MAPS_AND_NAVIGATION"	[21,"4.0.3 and up"]
# "MAPS_AND_NAVIGATION"	[7,"5.0 and up"]
# "MAPS_AND_NAVIGATION"	[5,"4.4 and up"]
# "MAPS_AND_NAVIGATION"	[5,"4.2 and up"]
# "MAPS_AND_NAVIGATION"	[5,"2.2 and up"]
# "MAPS_AND_NAVIGATION"	[4,"4.3 and up"]
# "MAPS_AND_NAVIGATION"	[4,"2.3.3 and up"]
# "MAPS_AND_NAVIGATION"	[1,"2.3 and up"]
# "MAPS_AND_NAVIGATION"	[1,"1.5 and up"]
# "MEDICAL"	[97,"4.0.3 and up"]
# "MEDICAL"	[85,"4.1 and up"]
# "MEDICAL"	[61,"4.4 and up"]
# "MEDICAL"	[53,"4.0 and up"]
# "MEDICAL"	[44,"5.0 and up"]
# "MEDICAL"	[24,"Varies with device"]
# "MEDICAL"	[22,"3.0 and up"]
# "MEDICAL"	[15,"4.3 and up"]
# "MEDICAL"	[12,"2.2 and up"]
# "MEDICAL"	[9,"4.2 and up"]
# "MEDICAL"	[8,"2.3.3 and up"]
# "MEDICAL"	[8,"2.1 and up"]
# "MEDICAL"	[6,"6.0 and up"]
# "MEDICAL"	[6,"2.3 and up"]
# "MEDICAL"	[3,"4.4W and up"]
# "MEDICAL"	[2,"7.0 and up"]
# "MEDICAL"	[2,"5.1 and up"]
# "MEDICAL"	[2,"3.2 and up"]
# "MEDICAL"	[2,"1.6 and up"]
# "MEDICAL"	[1,"8.0 and up"]
# "MEDICAL"	[1,"2.0 and up"]
# "NEWS_AND_MAGAZINES"	[81,"4.1 and up"]
# "NEWS_AND_MAGAZINES"	[63,"Varies with device"]
# "NEWS_AND_MAGAZINES"	[41,"4.4 and up"]
# "NEWS_AND_MAGAZINES"	[33,"4.0 and up"]
# "NEWS_AND_MAGAZINES"	[24,"4.0.3 and up"]
# "NEWS_AND_MAGAZINES"	[17,"5.0 and up"]
# "NEWS_AND_MAGAZINES"	[9,"4.2 and up"]
# "NEWS_AND_MAGAZINES"	[4,"2.3.3 and up"]
# "NEWS_AND_MAGAZINES"	[4,"2.3 and up"]
# "NEWS_AND_MAGAZINES"	[2,"2.2 and up"]
# "NEWS_AND_MAGAZINES"	[1,"6.0 and up"]
# "NEWS_AND_MAGAZINES"	[1,"4.4W and up"]
# "NEWS_AND_MAGAZINES"	[1,"4.3 and up"]
# "NEWS_AND_MAGAZINES"	[1,"3.0 and up"]
# "NEWS_AND_MAGAZINES"	[1,"1.6 and up"]
# "PARENTING"	[18,"4.0.3 and up"]
# "PARENTING"	[11,"4.1 and up"]
# "PARENTING"	[11,"4.0 and up"]
# "PARENTING"	[6,"4.4 and up"]
# "PARENTING"	[5,"4.2 and up"]
# "PARENTING"	[3,"Varies with device"]
# "PARENTING"	[3,"5.0 and up"]
# "PARENTING"	[2,"2.3 and up"]
# "PARENTING"	[1,"2.2 and up"]
# "PERSONALIZATION"	[78,"4.1 and up"]
# "PERSONALIZATION"	[60,"4.0.3 and up"]
# "PERSONALIZATION"	[54,"4.0 and up"]
# "PERSONALIZATION"	[38,"Varies with device"]
# "PERSONALIZATION"	[31,"2.3.3 and up"]
# "PERSONALIZATION"	[21,"4.4 and up"]
# "PERSONALIZATION"	[17,"5.0 and up"]
# "PERSONALIZATION"	[16,"2.3 and up"]
# "PERSONALIZATION"	[15,"2.1 and up"]
# "PERSONALIZATION"	[11,"2.2 and up"]
# "PERSONALIZATION"	[10,"7.0 and up"]
# "PERSONALIZATION"	[9,"1.6 and up"]
# "PERSONALIZATION"	[8,"4.2 and up"]
# "PERSONALIZATION"	[6,"4.3 and up"]
# "PERSONALIZATION"	[5,"3.0 and up"]
# "PERSONALIZATION"	[4,"6.0 and up"]
# "PERSONALIZATION"	[2,"NaN"]
# "PERSONALIZATION"	[2,"5.1 and up"]
# "PERSONALIZATION"	[2,"2.0 and up"]
# "PERSONALIZATION"	[1,"8.0 and up"]
# "PERSONALIZATION"	[1,"5.0 - 6.0"]
# "PERSONALIZATION"	[1,"3.2 and up"]
# "PHOTOGRAPHY"	[57,"Varies with device"]
# "PHOTOGRAPHY"	[57,"4.0 and up"]
# "PHOTOGRAPHY"	[56,"4.1 and up"]
# "PHOTOGRAPHY"	[46,"4.0.3 and up"]
# "PHOTOGRAPHY"	[23,"4.4 and up"]
# "PHOTOGRAPHY"	[20,"2.3 and up"]
# "PHOTOGRAPHY"	[16,"4.2 and up"]
# "PHOTOGRAPHY"	[14,"5.0 and up"]
# "PHOTOGRAPHY"	[11,"2.2 and up"]
# "PHOTOGRAPHY"	[10,"4.3 and up"]
# "PHOTOGRAPHY"	[7,"2.3.3 and up"]
# "PHOTOGRAPHY"	[6,"3.2 and up"]
# "PHOTOGRAPHY"	[4,"3.0 and up"]
# "PHOTOGRAPHY"	[2,"3.1 and up"]
# "PHOTOGRAPHY"	[2,"2.1 and up"]
# "PHOTOGRAPHY"	[1,"7.0 and up"]
# "PHOTOGRAPHY"	[1,"6.0 and up"]
# "PHOTOGRAPHY"	[1,"5.1 and up"]
# "PHOTOGRAPHY"	[1,"5.0 - 8.0"]
# "PRODUCTIVITY"	[105,"Varies with device"]
# "PRODUCTIVITY"	[71,"4.1 and up"]
# "PRODUCTIVITY"	[55,"4.0 and up"]
# "PRODUCTIVITY"	[45,"4.4 and up"]
# "PRODUCTIVITY"	[39,"4.0.3 and up"]
# "PRODUCTIVITY"	[27,"5.0 and up"]
# "PRODUCTIVITY"	[14,"4.2 and up"]
# "PRODUCTIVITY"	[13,"2.3 and up"]
# "PRODUCTIVITY"	[11,"2.2 and up"]
# "PRODUCTIVITY"	[10,"2.3.3 and up"]
# "PRODUCTIVITY"	[7,"4.3 and up"]
# "PRODUCTIVITY"	[6,"2.1 and up"]
# "PRODUCTIVITY"	[3,"6.0 and up"]
# "PRODUCTIVITY"	[3,"3.2 and up"]
# "PRODUCTIVITY"	[3,"3.1 and up"]
# "PRODUCTIVITY"	[3,"3.0 and up"]
# "PRODUCTIVITY"	[2,"2.0 and up"]
# "PRODUCTIVITY"	[2,"1.5 and up"]
# "PRODUCTIVITY"	[1,"7.0 and up"]
# "PRODUCTIVITY"	[1,"5.1 and up"]
# "PRODUCTIVITY"	[1,"5.0 - 8.0"]
# "PRODUCTIVITY"	[1,"4.4W and up"]
# "PRODUCTIVITY"	[1,"1.6 and up"]
# "SHOPPING"	[74,"4.1 and up"]
# "SHOPPING"	[55,"Varies with device"]
# "SHOPPING"	[49,"4.4 and up"]
# "SHOPPING"	[28,"4.0.3 and up"]
# "SHOPPING"	[21,"4.0 and up"]
# "SHOPPING"	[11,"5.0 and up"]
# "SHOPPING"	[5,"4.2 and up"]
# "SHOPPING"	[5,"2.2 and up"]
# "SHOPPING"	[4,"4.3 and up"]
# "SHOPPING"	[4,"3.0 and up"]
# "SHOPPING"	[2,"2.3.3 and up"]
# "SHOPPING"	[2,"2.3 and up"]
# "SOCIAL"	[75,"Varies with device"]
# "SOCIAL"	[68,"4.1 and up"]
# "SOCIAL"	[43,"4.0.3 and up"]
# "SOCIAL"	[25,"4.4 and up"]
# "SOCIAL"	[18,"4.0 and up"]
# "SOCIAL"	[14,"5.0 and up"]
# "SOCIAL"	[11,"4.3 and up"]
# "SOCIAL"	[11,"2.3 and up"]
# "SOCIAL"	[10,"4.2 and up"]
# "SOCIAL"	[6,"2.2 and up"]
# "SOCIAL"	[5,"3.0 and up"]
# "SOCIAL"	[4,"2.1 and up"]
# "SOCIAL"	[2,"2.3.3 and up"]
# "SOCIAL"	[1,"7.0 and up"]
# "SOCIAL"	[1,"2.0 and up"]
# "SOCIAL"	[1,"1.6 and up"]
# "SPORTS"	[113,"4.1 and up"]
# "SPORTS"	[52,"Varies with device"]
# "SPORTS"	[48,"4.4 and up"]
# "SPORTS"	[43,"4.0.3 and up"]
# "SPORTS"	[40,"5.0 and up"]
# "SPORTS"	[27,"4.0 and up"]
# "SPORTS"	[18,"4.2 and up"]
# "SPORTS"	[11,"2.3 and up"]
# "SPORTS"	[6,"3.0 and up"]
# "SPORTS"	[5,"4.3 and up"]
# "SPORTS"	[5,"2.3.3 and up"]
# "SPORTS"	[5,"2.1 and up"]
# "SPORTS"	[4,"2.2 and up"]
# "SPORTS"	[3,"5.1 and up"]
# "SPORTS"	[1,"6.0 and up"]
# "SPORTS"	[1,"2.0.1 and up"]
# "SPORTS"	[1,"2.0 and up"]
# "SPORTS"	[1,"1.5 and up"]
# "TOOLS"	[135,"4.1 and up"]
# "TOOLS"	[126,"4.0 and up"]
# "TOOLS"	[99,"Varies with device"]
# "TOOLS"	[94,"4.0.3 and up"]
# "TOOLS"	[56,"5.0 and up"]
# "TOOLS"	[54,"2.3 and up"]
# "TOOLS"	[42,"4.2 and up"]
# "TOOLS"	[41,"4.4 and up"]
# "TOOLS"	[41,"4.3 and up"]
# "TOOLS"	[29,"2.2 and up"]
# "TOOLS"	[22,"3.0 and up"]
# "TOOLS"	[22,"1.6 and up"]
# "TOOLS"	[18,"2.3.3 and up"]
# "TOOLS"	[18,"2.1 and up"]
# "TOOLS"	[11,"6.0 and up"]
# "TOOLS"	[7,"3.2 and up"]
# "TOOLS"	[6,"7.0 and up"]
# "TOOLS"	[6,"2.0 and up"]
# "TOOLS"	[6,"1.5 and up"]
# "TOOLS"	[3,"8.0 and up"]
# "TOOLS"	[2,"5.1 and up"]
# "TOOLS"	[1,"7.1 and up"]
# "TOOLS"	[1,"4.4W and up"]
# "TOOLS"	[1,"4.1 - 7.1.1"]
# "TOOLS"	[1,"3.1 and up"]
# "TOOLS"	[1,"1.0 and up"]
# "TRAVEL_AND_LOCAL"	[59,"Varies with device"]
# "TRAVEL_AND_LOCAL"	[44,"4.1 and up"]
# "TRAVEL_AND_LOCAL"	[41,"4.4 and up"]
# "TRAVEL_AND_LOCAL"	[29,"4.0 and up"]
# "TRAVEL_AND_LOCAL"	[26,"5.0 and up"]
# "TRAVEL_AND_LOCAL"	[24,"4.0.3 and up"]
# "TRAVEL_AND_LOCAL"	[10,"4.2 and up"]
# "TRAVEL_AND_LOCAL"	[8,"4.3 and up"]
# "TRAVEL_AND_LOCAL"	[4,"2.3.3 and up"]
# "TRAVEL_AND_LOCAL"	[3,"2.3 and up"]
# "TRAVEL_AND_LOCAL"	[3,"2.2 and up"]
# "TRAVEL_AND_LOCAL"	[2,"6.0 and up"]
# "TRAVEL_AND_LOCAL"	[2,"3.0 and up"]
# "TRAVEL_AND_LOCAL"	[1,"7.0 and up"]
# "TRAVEL_AND_LOCAL"	[1,"4.4W and up"]
# "TRAVEL_AND_LOCAL"	[1,"1.6 and up"]
# "VIDEO_PLAYERS"	[32,"Varies with device"]
# "VIDEO_PLAYERS"	[29,"4.1 and up"]
# "VIDEO_PLAYERS"	[21,"4.0.3 and up"]
# "VIDEO_PLAYERS"	[19,"4.0 and up"]
# "VIDEO_PLAYERS"	[17,"4.4 and up"]
# "VIDEO_PLAYERS"	[13,"5.0 and up"]
# "VIDEO_PLAYERS"	[11,"4.3 and up"]
# "VIDEO_PLAYERS"	[8,"2.3 and up"]
# "VIDEO_PLAYERS"	[6,"4.2 and up"]
# "VIDEO_PLAYERS"	[6,"3.0 and up"]
# "VIDEO_PLAYERS"	[4,"2.3.3 and up"]
# "VIDEO_PLAYERS"	[4,"2.2 and up"]
# "VIDEO_PLAYERS"	[2,"2.1 and up"]
# "VIDEO_PLAYERS"	[1,"7.1 and up"]
# "VIDEO_PLAYERS"	[1,"7.0 and up"]
# "VIDEO_PLAYERS"	[1,"1.6 and up"]
# "WEATHER"	[25,"Varies with device"]
# "WEATHER"	[14,"4.1 and up"]
# "WEATHER"	[13,"4.4 and up"]
# "WEATHER"	[7,"5.0 and up"]
# "WEATHER"	[5,"4.0 and up"]
# "WEATHER"	[5,"2.3 and up"]
# "WEATHER"	[3,"4.0.3 and up"]
# "WEATHER"	[2,"4.2 and up"]
# "WEATHER"	[2,"2.2 and up"]
# "WEATHER"	[2,"2.1 and up"]
# "WEATHER"	[1,"4.3 and up"]
# "WEATHER"	[1,"3.0 and up"]
# "WEATHER"	[1,"2.3.3 and up"]
# "WEATHER"	[1,"1.6 and up"]

# %% [markdown]
# **T** (60pts) In the review dataset which words have more occurrence in every application(output must be sorted on Count)
#
# > result:
# `<appname, {count, word1, word2} >`
#
# `hint:` use secondary sort

# %%
# %%writefile nikoo_big_data_hw1.py

from mrjob.job import MRJob,MRStep
#import pandas as pd
from operator import itemgetter
import re

class NumOfFrequentWords(MRJob):
    
    def steps(self):
        return [
            MRStep(
                mapper=self.mapper1,
                reducer=self.reducer1
            ),

            MRStep(
                reducer=self.reducer_sort
            )
        ]
    
    
    def mapper1(self,_, lines):
        allWords = []
        a = []
        for line in lines.split('\n'):
            app = line.split('∑')
            appName = app[0]
            a.append(appName)
            translated_review = app[1] = re.sub(r'[^\w]', ' ', app[1])
            for word in translated_review.split(' '):
                if word != "":
                    word = word.lower()
                    a.append(word)
            allWords.append(a)
        for i in range(0, len(allWords) ):
            for j in range(1, len(allWords[i]) ):
                yield (allWords[i][0], allWords[i][j]), 1
            
            
            
    def reducer1(self, appName_word, count):
        appName, word = appName_word
        yield appName, (word, sum(count))
        
     
           
    def reducer_sort(self, appName, word_count):
        word_count = sorted(word_count, key=itemgetter(1), reverse=True)  
        #yield appName, word_count
        
        for i in range(0, len(word_count) - 1):
            if word_count[i][1] == word_count[i+1][1]:
                yield appName, (word_count[i][1], word_count[i][0], word_count[i+1][0])
                break
                
         
 
          

if __name__ == '__main__':
    NumOfFrequentWords.run()
# Out:
# Overwriting nikoo_big_data_hw1.py

# %%
# !python nikoo_big_data_hw1.py googleplaystore_user_reviews.txt -q
# Out:
# "10 Best Foods for You"	[26,"best","great"]
# "104 \u627e\u5de5\u4f5c - \u627e\u5de5\u4f5c \u627e\u6253\u5de5 \u627e\u517c\u8077 \u5c65\u6b77\u5065\u6aa2 \u5c65\u6b77\u8a3a\u7642\u5ba4"	[12,"easy","the"]
# "11st"	[11,"and","is"]
# "1800 Contacts - Lens Store"	[14,"it","love"]
# "1LINE \u2013 One Line with One Touch"	[4,"ads","love"]
# "2018Emoji Keyboard \ud83d\ude02 Emoticons Lite -sticker&gif"	[8,"i","nan"]
# "21-Day Meditation Experience"	[21,"full","review"]
# "2Date Dating App, Love and matching"	[11,"app","dating"]
# "2GIS: directory & navigator"	[11,"but","in"]
# "2RedBeans"	[4,"app","it"]
# "2ndLine - Second Phone Number"	[9,"calls","occurred"]
# "30 Day Fitness Challenge - Workout at Home"	[9,"great","nan"]
# "365Scores - Live Scores"	[3,"highlights","please"]
# "3D Live Neon Weed Launcher"	[1,"best","it"]
# "4 in a Row"	[5,"i","it"]
# "4K Wallpapers and Ultra HD Backgrounds"	[3,"look","re"]
# "591\u623f\u5c4b\u4ea4\u6613-\u79df\u5c4b\u3001\u4e2d\u53e4\u5c4b\u3001\u65b0\u5efa\u6848\u3001\u5be6\u50f9\u767b\u9304\u3001\u5225\u5885\u900f\u5929\u3001\u516c\u5bd3\u5957\u623f\u3001\u6377\u904b\u3001\u8cb7\u623f\u8ce3\u623f\u884c\u60c5\u3001\u623f\u50f9\u623f\u8cb8\u67e5\u8a62"	[8,"can","for"]
# "591\u623f\u5c4b\u4ea4\u6613-\u9999\u6e2f"	[3,"english","of"]
# "7 Cups: Anxiety & Stress Chat"	[3,"bugs","listeners"]
# "7 Day Food Journal Challenge"	[3,"7","every"]
# "7 Minute Workout"	[4,"app","good"]
# "7 Weeks - Habit & Goal Tracker"	[7,"but","the"]
# "8 Ball Pool"	[36,"really","you"]
# "850 Sports News Digest"	[9,"app","news"]
# "8fit Workouts & Meal Planner"	[32,"day","s"]
# "95Live -SG#1 Live Streaming App"	[10,"app","is"]
# "A Call From Santa Claus!"	[10,"good","like"]
# "A Word A Day"	[2,"i","it"]
# "A&E - Watch Full Episodes of TV Shows"	[8,"great","shows"]
# "A+ Gallery - Photos & Videos"	[6,"gallery","photos"]
# "A+ Mobile"	[10,"check","great"]
# "ABC Kids - Tracing & Phonics"	[11,"i","my"]
# "ABC News - US & World News"	[38,"i","news"]
# "ABC Preschool Free"	[5,"brother","game"]
# "ABCmouse.com"	[8,"son","work"]
# "AC - Tips & News for Android\u2122"	[7,"good","t"]
# "ACE Elite"	[8,"ace","love"]
# "AD - Nieuws, Sport, Regio & Entertainment"	[12,"it","news"]
# "AMC Theatres"	[3,"good","tickets"]
# "ANA"	[10,"i","the"]
# "AOL - News, Mail & Video"	[8,"email","emails"]
# "AP Mobile - Breaking News"	[12,"open","the"]
# "APE Weather ( Live Forecast)"	[4,"really","weather"]
# "APUS Launcher - Theme, Wallpaper, Hide Apps"	[7,"good","it"]
# "ARY NEWS URDU"	[6,"good","nan"]
# "ARY NEWS"	[7,"nan","news"]
# "ASOS"	[19,"asos","love"]
# "ASUS Calling Screen"	[7,"asus","calling"]
# "ASUS Cover for ZenFone 2"	[2,"a","as"]
# "ASUS Quick Memo"	[1,"2","app"]
# "ASUS Sound Recorder"	[3,"nice","very"]
# "ASUS SuperNote"	[5,"can","it"]
# "AT&T Navigator: Maps, Traffic"	[11,"nan","this"]
# "AT&T Smart Wi-Fi"	[9,"i","wifi"]
# "AT&T Visual Voicemail"	[11,"it","t"]
# "AVG Cleaner \u2013 Speed, Battery & Memory Booster"	[10,"app","s"]
# "Abs Training-Burn belly fat"	[12,"ads","day"]
# "Account Manager"	[11,"can","it"]
# "Accounting App - Zoho Books"	[9,"business","nan"]
# "AccuWeather: Daily Forecast & Live Weather Reports"	[10,"it","update"]
# "Acorn TV: World-class TV from Britain and Beyond"	[9,"full","video"]
# "Acorns - Invest Spare Change"	[2,"cancel","change"]
# "AdWords Express"	[9,"great","i"]
# "Ada - Your Health Guide"	[18,"ada","helpful"]
# "Add Text To Photo"	[6,"nan","the"]
# "Adobe Acrobat Reader"	[33,"cloud","like"]
# "Adobe Photoshop Express:Photo Editor Collage Maker"	[13,"editing","great"]
# "Advanced Task Killer"	[7,"it","kill"]
# "Agar.io"	[29,"play","this"]
# "Age Calculator"	[8,"nan","need"]
# "Agoda \u2013 Hotel Booking Deals"	[8,"booking","hotel"]
# "Air Traffic"	[5,"altitude","flight"]
# "AirAsia"	[7,"login","t"]
# "AirBrush: Easy Photo Editor"	[5,"app","good"]
# "Airbnb"	[14,"great","it"]
# "Airport + Flight Tracker Radar"	[9,"flight","t"]
# "Airway Ex - Intubate. Anesthetize. Train."	[8,"great","t"]
# "Akinator"	[13,"ads","character"]
# "AlReader -any text book reader"	[10,"best","reader"]
# "Alarm Clock Free"	[8,"like","work"]
# "Alarm Clock"	[8,"s","t"]
# "Alfred Home Security Camera"	[4,"camera","cameras"]
# "AliExpress - Smarter Shopping, Better Living"	[12,"buy","like"]
# "All Email Providers"	[2,"ads","i"]
# "All Events in City"	[7,"app","i"]
# "All Football - Latest News & Videos"	[7,"app","it"]
# "All Football GO- Live Score, Games"	[4,"ever","live"]
# "All Language Translator Free"	[9,"i","it"]
# "All Maths Formulas"	[7,"best","nan"]
# "All Mental disorders"	[10,"best","m"]
# "All Social Networks"	[7,"get","t"]
# "All Video Downloader 2018"	[4,"it","very"]
# "All-In-One Toolbox: Cleaner, Booster, App Manager"	[4,"ads","good"]
# "All-in-One Mahjong 3 FREE"	[1,"go","i"]
# "Allegiant"	[1,"airline","better"]
# "Allrecipes Dinner Spinner"	[6,"app","love"]
# "Alto's Adventure"	[36,"ads","playing"]
# "Amazon Drive"	[9,"it","s"]
# "Amazon FreeTime \u2013 Kids\u2019 Videos, Books, & TV shows"	[11,"able","books"]
# "Amazon Kindle"	[23,"nan","new"]
# "Amazon Prime Video"	[2,"great","it"]
# "Amazon Shopping"	[11,"app","s"]
# "Amazon for Tablets"	[12,"australian","store"]
# "American Airlines"	[9,"gate","it"]
# "Amex Mobile"	[6,"card","credit"]
# "Amino: Communities and Chats"	[18,"app","like"]
# "Amtrak"	[9,"app","ticket"]
# "Anatomy Learning - 3D Atlas"	[11,"screen","would"]
# "Ancestry"	[8,"great","the"]
# "AndroZip\u2122 FREE File Manager"	[11,"app","file"]
# "Android Auto - Maps, Media, Messaging & Voice"	[13,"great","would"]
# "Android Messages"	[12,"messaging","time"]
# "Anger of stick 5 : zombie"	[1,"better","cool"]
# "Angry Birds 2"	[11,"get","nan"]
# "Angry Birds Classic"	[70,"fun","this"]
# "Angry Birds Rio"	[7,"angry","birds"]
# "Animal Planet GO"	[3,"animal","screen"]
# "Animated Photo Editor"	[5,"good","it"]
# "Anime Avatar Creator: Make Your Own Avatar"	[15,"make","s"]
# "Anime Manga Coloring Book"	[6,"color","good"]
# "Anthem Anywhere"	[17,"can","information"]
# "Anthem BC Anywhere"	[9,"nan","work"]
# "Any.do: To-do list, Calendar, Reminders & Planner"	[19,"do","like"]
# "Apartment Decorating Ideas"	[1,"like","me"]
# "Apartment List: Housing, Apt, and Property Rentals"	[10,"apartment","apartments"]
# "Apartment, Home Rental Search: Realtor.com Rentals"	[3,"find","look"]
# "Apartments & Rentals - Zillow"	[9,"love","place"]
# "Apartments.com Rental Search"	[11,"nan","this"]
# "Apex Launcher"	[23,"drawer","screen"]
# "Apk Installer"	[13,"apk","nan"]
# "App vault"	[4,"app","useless"]
# "AppLock - Fingerprint"	[10,"it","lock"]
# "AppLock"	[7,"app","screen"]
# "Apple Daily \u860b\u679c\u52d5\u65b0\u805e"	[7,"i","update"]
# "Aprender ingl\u00e9s con Wlingua"	[18,"application","very"]
# "Archos File Manager"	[7,"archos","phone"]
# "Arrow.io"	[13,"good","this"]
# "Asana: organize team projects"	[11,"tasks","the"]
# "Ascape VR: 360\u00b0 Virtual Travel"	[3,"data","download"]
# "Asphalt 8: Airborne"	[25,"play","the"]
# "Associated Credit Union Mobile"	[10,"easy","great"]
# "Asteroids 3D live wallpaper"	[10,"i","it"]
# "Atlan3D Navigation: Korea navigator"	[16,"not","to"]
# "AutoCAD - DWG Viewer & Editor"	[6,"free","it"]
# "AutoScout24 Switzerland \u2013 Find your new car"	[5,"app","good"]
# "Avakin Life - 3D virtual world"	[23,"like","s"]
# "Aviary Effects: Classic"	[9,"classic","photo"]
# "Aviary Stickers: Free Pack"	[11,"good","stickers"]
# "Azar"	[9,"gems","good"]
# "Azpen eReader"	[3,"app","azpen"]
# "B612 - Beauty & Filter Camera"	[4,"and","good"]
# "BBC Media Player"	[12,"video","work"]
# "BBC News"	[17,"get","time"]
# "BBC Sport"	[10,"live","sport"]
# "BBM - Free Calls & Messages"	[7,"ads","app"]
# "BBVA Compass Banking"	[6,"check","this"]
# "BBVA Spain"	[6,"a","can"]
# "BBW Dating & Curvy Singles Chat- LargeFriends"	[12,"can","like"]
# "BBW Dating & Plus Size Chat"	[33,"it","people"]
# "BBWCupid - BBW Dating App"	[9,"messages","t"]
# "BELONG Beating Cancer Together"	[7,"good","great"]
# "BEST CAR SOUNDS"	[6,"nan","nice"]
# "BET NOW - Watch Shows"	[27,"cable","it"]
# "BEYBLADE BURST app"	[7,"bey","love"]
# "BIG Launcher"	[9,"app","phone"]
# "BLK - Swipe. Match. Chat."	[7,"black","it"]
# "BZWBK24 mobile"	[7,"application","is"]
# "B\u00c1O M\u1edaI - \u0110\u1ecdc B\u00e1o, Tin T\u1ee9c 24h"	[10,"a","to"]
# "BaBe - Baca Berita"	[3,"a","to"]
# "BaBe Lite - Baca Berita Hemat Kuota"	[4,"i","the"]
# "BaBe+ - Berita Indonesia"	[3,"good","news"]
# "Babbel \u2013 Learn Languages"	[8,"could","good"]
# "Babbel \u2013 Learn Spanish"	[5,"easy","far"]
# "Baby ABC in box! Kids alphabet games for toddlers!"	[8,"good","my"]
# "Baby Monitor"	[12,"s","works"]
# "Baby Name Together"	[6,"good","it"]
# "Baby Panda Care"	[7,"hate","love"]
# "Baby Panda Learns Shapes"	[8,"baby","it"]
# "Baby Panda Musical Genius"	[7,"love","s"]
# "Baby Panda\u2019s Juice Shop"	[1,"add","characters"]
# "Baby Tiger Care - My Cute Virtual Pet Friend"	[1,"best","d"]
# "Baby puzzles"	[8,"kids","year"]
# "Baca- Berita Terbaru, Informasi, Gosip dan Politik"	[7,"and","nan"]
# "Backgrounds (HD Wallpapers)"	[8,"there","wallpaper"]
# "Backgrounds HD (Wallpapers)"	[4,"not","wallpaper"]
# "BaconReader for Reddit"	[7,"best","it"]
# "Bad Piggies"	[28,"el","levels"]
# "Badoo - Free Chat & Dating App"	[15,"fake","good"]
# "Bagan - Myanmar Keyboard"	[9,"keyboard","the"]
# "Banco Ita\u00fa"	[11,"a","does"]
# "Banco do Brasil"	[8,"good","need"]
# "Bancomer m\u00f3vil"	[23,"recognition","use"]
# "Banfield Pet Health Tracker"	[26,"app","time"]
# "Bangla Newspaper \u2013 Prothom Alo"	[7,"app","log"]
# "Banjo"	[8,"get","instagram"]
# "Bank of America Mobile Banking"	[10,"app","phone"]
# "BankMobile Vibe App"	[4,"app","deposits"]
# "Banorte Movil"	[10,"of","very"]
# "Banque Populaire"	[13,"the","to"]
# "Barbie Life\u2122"	[6,"fun","games"]
# "Barbie Magical Fashion"	[13,"good","like"]
# "Barbie\u2122 Fashion Closet"	[18,"fun","love"]
# "Barclays US for Android"	[9,"app","notifications"]
# "Barcode Scanner"	[7,"barcode","scanner"]
# "Baritastic - Bariatric Tracker"	[10,"app","love"]
# "Baseball Boy!"	[15,"every","it"]
# "Basketball FRVR - Shoot the Hoop and Slam Dunk!"	[6,"fun","it"]
# "Basketball Stars"	[14,"basketball","good"]
# "Bathroom Decorating Ideas"	[6,"i","ideas"]
# "Battlelands Royale"	[36,"pass","the"]
# "Be A Legend: Soccer"	[25,"even","load"]
# "BeSoccer - Soccer Live Score"	[7,"it","the"]
# "BeWild Free Dating & Chat App"	[14,"card","chat"]
# "Beautiful Design Birthday Cake"	[4,"game","nan"]
# "Beautiful Widgets Free"	[15,"location","time"]
# "Beautiful Widgets Pro"	[12,"still","the"]
# "Beauty Camera - Selfie Camera"	[13,"ad","t"]
# "Beauty Makeup Snappy Collage Photo Editor - Lidow"	[1,"cannot","device"]
# "BeautyPlus - Easy Photo Editor & Selfie Camera"	[1,"good","i"]
# "Bed Time Fan - White Noise Sleep Sounds"	[1,"app","d"]
# "Best Car Wallpapers"	[1,"and","be"]
# "Best Fiends - Free Puzzle Game"	[1,"addictive","best"]
# "Best Ovulation Tracker Fertility Calendar App Glow"	[1,"5","calendar"]
# "Best Wallpapers Backgrounds(100,000+ 4K HD)"	[2,"cool","it"]
# "Best Wallpapers QHD"	[7,"like","very"]
# "BestCam Selfie-selfie, beauty camera, photo editor"	[6,"i","nice"]
# "BetterMe: Weight Loss Workouts"	[8,"exercises","s"]
# "Betterment"	[9,"betterment","money"]
# "BeyondMenu Food Delivery"	[5,"like","restaurant"]
# "BeyondPod Podcast Manager"	[24,"it","update"]
# "Bible"	[19,"app","full"]
# "Big Days - Events Countdown"	[8,"great","love"]
# "BigOven Recipes, Meal Planner, Grocery List & More"	[17,"love","recipe"]
# "BiggerCity: Chat for gay bears, chubs & chasers"	[13,"great","it"]
# "Bike Computer - GPS Cycling Tracker"	[7,"good","need"]
# "Binaural Beats Meditation"	[5,"does","it"]
# "Binaural Beats Therapy"	[11,"the","this"]
# "BioLife Plasma Services"	[10,"even","reschedule"]
# "Birdays \u2013 Birthday reminder"	[13,"app","birthday"]
# "Birds Sounds Ringtones & Wallpapers"	[6,"like","sounds"]
# "Black People Meet Singles Date"	[6,"love","message"]
# "Block Puzzle Classic Legend !"	[10,"enjoy","interesting"]
# "Block Puzzle"	[33,"like","love"]
# "Blogaway for Android (Blogger)"	[9,"can","t"]
# "Blogger"	[21,"it","post"]
# "Bloglovin'"	[8,"app","read"]
# "Blood Donor"	[16,"blood","donor"]
# "Blood Pressure Log - MyDiary"	[17,"app","bp"]
# "Blood Pressure"	[6,"doctor","like"]
# "Blood Pressure(BP) Diary"	[8,"access","t"]
# "Bloomberg Professional"	[8,"i","version"]
# "Bloomberg: Market & Financial News"	[7,"pay","radio"]
# "Blossom Blast Saga"	[12,"lives","play"]
# "BluTV"	[6,"of","with"]
# "Blur Image Background Editor (Blur Photo Editor)"	[7,"good","the"]
# "Blur Image Background"	[2,"good","it"]
# "Booking.com Travel Deals"	[21,"t","time"]
# "Bowmasters"	[114,"ads","it"]
# "Box"	[15,"best","box"]
# "Boxed Wholesale"	[12,"love","prices"]
# "Boys Photo Editor - Six Pack & Men's Suit"	[3,"nice","s"]
# "Brain Waves - Binaural Beats"	[9,"app","great"]
# "Branch"	[7,"like","loans"]
# "Brasileir\u00e3o Pro 2018 - S\u00e9rie A e B"	[16,"good","it"]
# "Breaking News, Local news, Attacks and Alerts Free"	[10,"news","s"]
# "Brightest Flashlight Free \u00ae"	[3,"app","it"]
# "Brightest LED Flashlight"	[5,"great","light"]
# "Brilliant"	[8,"app","learn"]
# "Brit + Co"	[5,"articles","frustrating"]
# "British Airways"	[4,"can","date"]
# "Browser 4G"	[4,"fast","nice"]
# "Bualuang mBanking"	[21,"do","i"]
# "Bubble Shooter 2"	[2,"connect","fun"]
# "Bubble Shooter Genies"	[2,"advertisements","get"]
# "Bubble Shooter Space"	[3,"bubble","i"]
# "Bubble Shooter"	[24,"good","love"]
# "Bubble Witch 3 Saga"	[10,"get","level"]
# "Buienradar - weer"	[14,"and","rain"]
# "Build a Bridge!"	[10,"great","level"]
# "Bukalapak - Jual Beli Online"	[14,"in","of"]
# "BukuBayi - Perkembangan Bayi"	[8,"application","very"]
# "Burner - Free Phone Number"	[5,"it","subscription"]
# "Buscap\u00e9 - Ofertas e descontos"	[2,"category","for"]
# "Business Calendar 2"	[6,"lists","time"]
# "Butterfly Live Wallpaper"	[12,"i","nan"]
# "Buzz Launcher-Smart&Free Theme"	[9,"but","love"]
# "BuzzFeed: News, Tasty, Quizzes"	[13,"sign","would"]
# "C Programming"	[8,"learn","would"]
# "C++ Programming"	[13,"it","many"]
# "C++ Tutorials"	[6,"ads","nice"]
# "CAIXA"	[30,"and","the"]
# "CALCU\u2122 Stylish Calculator Free"	[6,"great","this"]
# "CATS: Crash Arena Turbo Stars"	[11,"please","t"]
# "CBS News"	[1,"feature","hoping"]
# "CBS Sports App - Scores, News, Stats & Watch Live"	[51,"good","see"]
# "CBS Sports Fantasy"	[7,"ads","good"]
# "CDL Practice Test 2018 Edition"	[5,"get","really"]
# "CIA - Caller ID & Call Blocker"	[3,"good","review"]
# "CM Browser - Ad Blocker , Fast Download , Privacy"	[2,"best","ever"]
# "CM Flashlight (Compass, SOS)"	[1,"bright","compass"]
# "CM Launcher 3D - Theme, Wallpapers, Efficient"	[3,"it","launcher"]
# "CM Locker - Security Lockscreen"	[28,"it","phone"]
# "CMB Free Dating App"	[14,"app","it"]
# "CNBC: Breaking Business News & Live Market Data"	[7,"app","stock"]
# "CNN Breaking US & World News"	[23,"live","that"]
# "COOKING MAMA Let's Cook!"	[20,"game","it"]
# "CVS Caremark"	[6,"cvs","order"]
# "CW Seed"	[6,"free","watch"]
# "CWT To Go"	[6,"app","it"]
# "Cache Cleaner-DU Speed Booster (booster & cleaner)"	[9,"i","it"]
# "Caf - Mon Compte"	[1,"5","almost"]
# "Calculator - free calculator, multi calculator app"	[1,"5","among"]
# "Calculator - unit converter"	[1,"calculator","comma"]
# "Calculator Plus Free"	[1,"again","ago"]
# "Calculator with Percent (Free)"	[1,"actually","app"]
# "Calendar Widget Month + Agenda"	[1,"already","appearance"]
# "Calendar+ Schedule Planner App"	[3,"calendar","love"]
# "Call Blocker"	[2,"annoying","block"]
# "Call Control - Call Blocker"	[2,"block","i"]
# "Call of Duty:Black Ops Zombies"	[4,"game","online"]
# "CallApp: Caller ID, Blocker & Phone Call Recorder"	[1,"and","app"]
# "Caller ID +"	[1,"another","bitdefender"]
# "Calls & Text by Mo+"	[2,"credits","free"]
# "Calls Blacklist - Call Blocker"	[3,"block","does"]
# "Calm - Meditate, Sleep, Relax"	[19,"it","sleep"]
# "Calorie Counter & Diet Tracker"	[51,"food","like"]
# "Calorie Counter - EasyFit free"	[15,"food","good"]
# "Calorie Counter - Macros"	[48,"foods","love"]
# "Calorie Counter - MyFitnessPal"	[51,"food","s"]
# "Calorie Counter - MyNetDiary"	[35,"app","weight"]
# "Cameringo Lite. Filters Camera"	[1,"amazing","awesome"]
# "Candy Bomb"	[12,"love","nice"]
# "Candy Camera - selfie, beauty camera, photo editor"	[27,"app","filters"]
# "Candy Crush Jelly Saga"	[16,"level","not"]
# "Candy Crush Saga"	[90,"get","like"]
# "Candy Crush Soda Saga"	[32,"fix","the"]
# "Candy Day"	[7,"it","love"]
# "Candy Pop Story"	[10,"it","play"]
# "Candy Smash"	[6,"it","s"]
# "Candy selfie - photo editor, live filter camera"	[4,"and","best"]
# "Canva: Poster, banner, card maker & graphic design"	[8,"canva","great"]
# "Canvas Student"	[3,"i","loaded"]
# "Cat Sim Online: Play with Cats"	[17,"cute","make"]
# "Caviar - Food Delivery"	[7,"fees","great"]
# "Chakra Cleansing"	[5,"chakra","good"]
# "Championat"	[14,"it","on"]
# "Chapters: Interactive Stories"	[13,"it","make"]
# "Chase Mobile"	[14,"app","chase"]
# "Chat Rooms, Avatars, Date - Galaxy"	[24,"galaxy","it"]
# "ChatVideo Meet new people"	[5,"chat","good"]
# "Cheap Flights & Hotels momondo"	[9,"good","price"]
# "Cheap hotel deals and discounts \u2014 Hotellook"	[6,"good","number"]
# "CheapTickets \u2013 Hotels, Flights & Travel Deals"	[5,"cheap","great"]
# "Cheapflights \u2013 Flight Search"	[5,"flights","great"]
# "CheckPoints \ud83c\udfc6 Rewards App"	[8,"5","earn"]
# "Checkers \u2714\ufe0f"	[5,"like","play"]
# "Checkout 51: Grocery coupons"	[8,"receipts","t"]
# "Choice Hotels"	[3,"hotels","it"]
# "Choices: Stories You Play"	[43,"diamonds","game"]
# "Christian Dating For Free App"	[22,"christian","free"]
# "Chrome Beta"	[6,"new","working"]
# "Chrome Dev"	[11,"chrome","s"]
# "Cinemark Theatres"	[12,"buy","crashes"]
# "Cisco Webex Meetings"	[8,"call","meeting"]
# "Cisco Webex Teams"	[7,"message","this"]
# "Citi Mobile\u00ae"	[13,"get","t"]
# "Citibanamex Movil"	[10,"for","good"]
# "Citizens Bank Mobile Banking"	[14,"bank","it"]
# "CityMaps2Go Plan Trips Travel Guide Offline Maps"	[9,"find","offline"]
# "Claro"	[9,"not","to"]
# "Clash Royale"	[92,"cards","it"]
# "Clash of Clans"	[13,"also","play"]
# "Color Flashlight"	[4,"color","i"]
# "Color Road"	[11,"s","time"]
# "Color Touch Effects"	[6,"colors","easy"]
# "Color by Number - Draw Sandbox Pixel Art"	[19,"game","s"]
# "Color by Number \u2013 New Coloring Book"	[11,"could","great"]
# "ColorFil - Adult Coloring Book"	[10,"game","great"]
# "ColorNote Notepad Notes"	[41,"easy","lists"]
# "ColorSnap\u00ae Visualizer"	[8,"this","work"]
# "Colorfit - Drawing & Coloring"	[15,"coloring","diamonds"]
# "Colorful Glitter Neon Butterfly Keyboard Theme"	[4,"it","nice"]
# "Colorfy: Coloring Book for Adults - Free"	[40,"color","get"]
# "Coloring & Learn"	[5,"ads","game"]
# "Coloring book moana"	[14,"it","nan"]
# "Comedy Central"	[18,"show","watch"]
# "Common Core"	[4,"common","core"]
# "Comptia A+ 220-901 & 220-902"	[4,"app","good"]
# "ConnectLine"	[12,"aids","oticon"]
# "Contacts"	[16,"phone","this"]
# "Contacts+"	[9,"contacts","good"]
# "Content Transfer"	[11,"it","old"]
# "ConvertPad - Unit Converter"	[10,"app","screen"]
# "Cookbook Recipes"	[8,"easy","great"]
# "Cooking Channel"	[4,"app","free"]
# "Cooking Fever"	[33,"playing","time"]
# "Cooking Madness - A Chef's Restaurant Games"	[11,"get","levels"]
# "Cookpad"	[7,"recipes","search"]
# "Cool Popular Ringtones 2018 \ud83d\udd25"	[6,"it","nice"]
# "Cool Reader"	[12,"book","card"]
# "Couch to 10K Running Trainer"	[14,"10k","it"]
# "Couch to 5K by RunDouble"	[7,"great","like"]
# "Couchsurfing Travel App"	[10,"messages","s"]
# "Cougar Dating Life : Date Older Women Sugar Mummy"	[20,"people","you"]
# "Couple - Relationship App"	[16,"great","the"]
# "Credit Karma"	[8,"good","karma"]
# "Credit Sesame"	[8,"got","t"]
# "CreditWise from Capital One"	[8,"it","would"]
# "Crew - Free Messaging and Scheduling"	[14,"communication","easy"]
# "Cricbuzz - Live Cricket Scores & News"	[13,"app","cricket"]
# "Cricket Visual Voicemail"	[16,"speaker","the"]
# "Crossy Road"	[11,"good","play"]
# "Crunchyroll - Everything Anime"	[42,"even","video"]
# "Current debit card and app made for teens"	[12,"card","it"]
# "Curriculum vitae App CV Builder Free Resume Maker"	[13,"cv","it"]
# "Curso de Ingles Gratis"	[8,"the","you"]
# "Cut the Rope 2"	[16,"cute","time"]
# "Cut the Rope FULL FREE"	[8,"ad","cute"]
# "Cycling - Bike Tracker"	[5,"distance","good"]
# "Cymera Camera- Photo Editor, Filter,Collage,Layout"	[14,"good","ve"]
# "Czech Public Transport IDOS"	[9,"the","to"]
# "DC Comics"	[8,"comic","dc"]
# "DC Super Hero Girls\u2122"	[21,"it","like"]
# "DEAD TARGET: FPS Zombie Apocalypse Survival Games"	[19,"best","love"]
# "DEER HUNTER 2018"	[2,"hunt","reinstall"]
# "DELISH KITCHEN - \u7121\u6599\u30ec\u30b7\u30d4\u52d5\u753b\u3067\u6599\u7406\u3092\u697d\u3057\u304f\u30fb\u7c21\u5358\u306b\uff01"	[7,"easy","i"]
# "DINO HUNTER: DEADLY SHORES"	[23,"but","good"]
# "DIY Garden Ideas"	[7,"good","great"]
# "DIY On A Budget"	[11,"great","ideas"]
# "DMV Permit Practice Test 2018 Edition"	[12,"get","great"]
# "DRAGON BALL LEGENDS"	[32,"even","s"]
# "DSLR Camera Hd Ultra Professional"	[9,"add","good"]
# "DStv Now"	[13,"since","update"]
# "DU Browser\u2014Browse fast & fun"	[12,"engine","video"]
# "DU Recorder \u2013 Screen Recorder, Video Editor, Live"	[29,"record","recording"]
# "Daily Workouts - Exercise Fitness Routine Trainer"	[1,"great","it"]
# "Daily Yoga - Yoga Fitness Plans"	[6,"app","really"]
# "Dailyhunt (Newshunt) - Latest News, Viral Videos"	[3,"anti","videos"]
# "Dairy Queen"	[2,"dq","i"]
# "Daniel Tiger for Parents"	[3,"i","it"]
# "DashClock Widget"	[1,"appear","appears"]
# "Dashlane Free Password Manager"	[3,"app","pw"]
# "Dating App, Flirt & Chat : W-Match"	[1,"20","account"]
# "Dating for 50 plus Mature Singles \u2013 FINALLY"	[2,"far","good"]
# "Daum Mail - \ub2e4\uc74c \uba54\uc77c"	[2,"app","emails"]
# "Davis's Drug Guide for Nurses"	[1,"app","clear"]
# "Davis's Drug Guide"	[2,"access","app"]
# "Debonairs Pizza"	[3,"order","store"]
# "Delivery Club\u2013\u0414\u043e\u0441\u0442\u0430\u0432\u043a\u0430 \u0435\u0434\u044b:\u043f\u0438\u0446\u0446\u0430,\u0441\u0443\u0448\u0438,\u0431\u0443\u0440\u0433\u0435\u0440,\u0441\u0430\u043b\u0430\u0442"	[11,"in","to"]
# "Delta Dental"	[8,"try","useless"]
# "Despegar.com Hoteles y Vuelos"	[14,"very","you"]
# "Detector de Radares Gratis"	[4,"excellent","i"]
# "Device Help"	[9,"option","phone"]
# "Diabetes & Diet Tracker"	[20,"great","track"]
# "Diabetes:M"	[10,"easy","this"]
# "Diamond Zipper Lock Screen"	[6,"love","nan"]
# "Diary with lock password"	[10,"can","s"]
# "Diary with lock"	[33,"get","really"]
# "Dictionary - Merriam-Webster"	[5,"dictionary","the"]
# "Die TK-App \u2013 alles im Griff"	[6,"and","does"]
# "Digg"	[14,"digg","it"]
# "DigiCal Calendar Agenda"	[8,"google","widget"]
# "Digit Save Money Automatically"	[24,"it","nan"]
# "Digital Alarm Clock"	[18,"time","work"]
# "Dil Mil"	[8,"matches","the"]
# "Dino War: Rise of Beasts"	[7,"new","the"]
# "Dinosaur Simulator: Dino World"	[2,"ads","fun"]
# "Discover Mobile"	[2,"never","the"]
# "Disney Heroes: Battle Mode"	[2,"game","i"]
# "Disney Magic Kingdoms: Build Your Own Magical Park"	[15,"get","it"]
# "DisneyNOW \u2013 TV Shows & Games"	[21,"episodes","tv"]
# "Divar"	[12,"and","is"]
# "Do It Later: Tasks & To-Dos"	[8,"tasks","to"]
# "Docs To Go\u2122 Free Office Suite"	[12,"good","it"]
# "Doctor On Demand"	[8,"doctor","great"]
# "Doctor Pets"	[6,"like","pets"]
# "Dog Licks Screen Wallpaper"	[7,"dog","love"]
# "Dog Run - Pet Dog Simulator"	[18,"subway","surfers"]
# "Dog Sim Online: Raise a Family"	[5,"game","i"]
# "Domino's Pizza USA"	[28,"s","the"]
# "Dominos Game \u2714\ufe0f"	[5,"dominoes","i"]
# "Domofond \u041d\u0435\u0434\u0432\u0438\u0436\u0438\u043c\u043e\u0441\u0442\u044c. \u041a\u0443\u043f\u0438\u0442\u044c, \u0441\u043d\u044f\u0442\u044c \u043a\u0432\u0430\u0440\u0442\u0438\u0440\u0443."	[14,"a","is"]
# "Doodle Jump"	[16,"it","love"]
# "Door Lock Screen"	[3,"app","like"]
# "DoorDash - Food Delivery"	[14,"food","it"]
# "Dosecast - Medication Reminder"	[13,"app","it"]
# "Down Dog: Great Yoga Anywhere"	[14,"m","ve"]
# "Dr. Oetker Rezeptideen"	[7,"and","pictures"]
# "Dr. Panda & Toto's Treehouse"	[16,"my","turtle"]
# "Dr. Panda Restaurant 3"	[8,"love","s"]
# "Dr. Panda Town: Vacation"	[8,"get","this"]
# "DraftKings - Daily Fantasy Sports"	[6,"easy","money"]
# "Dragon Hills"	[6,"fun","good"]
# "Draw A Stickman"	[1,"draw","epic"]
# "Draw In"	[2,"boring","fun"]
# "Draw Your Game"	[2,"game","is"]
# "Draw a Stickman: EPIC 2"	[2,"game","games"]
# "Drawing for Kids Learning Games for Toddlers age 3"	[1,"2","colours"]
# "Dream League Soccer 2018"	[6,"game","i"]
# "DreamTrips"	[9,"dreamtrips","love"]
# "DreamWorks Friends"	[12,"it","my"]
# "Dresses Ideas & Fashions +3000"	[5,"dress","good"]
# "Droid Zap by Motorola"	[12,"install","s"]
# "DroidAdmin for Android - Advice"	[3,"brilliant","don"]
# "Dropbox"	[8,"free","google"]
# "Drugs.com Medication Guide"	[14,"app","it"]
# "Dude Perfect 2"	[30,"good","it"]
# "Dumb Ways to Die 2: The Games"	[13,"ads","many"]
# "Dungeon Hunter Champions: Epic Online Action RPG"	[8,"5","great"]
# "Dunkin' Donuts"	[10,"add","on"]
# "Duolingo: Learn Languages Free"	[62,"really","would"]
# "DuraSpeed"	[7,"background","my"]
# "E*TRADE Mobile"	[8,"nan","the"]
# "Easy - taxi, car, ridesharing"	[10,"a","good"]
# "Easy Hair Style Design"	[4,"hair","it"]
# "Easy Healthy Recipes"	[3,"food","it"]
# "Easy Installer - Apps On SD"	[7,"i","it"]
# "Easy Makeup Tutorials"	[5,"good","like"]
# "Easy Origami Ideas"	[8,"good","it"]
# "Easy Recipes"	[5,"great","love"]
# "Easy Voice Recorder"	[8,"good","phone"]
# "EasyBib: Citation Generator"	[8,"app","can"]
# "Eat Fit - Diet and Health Free"	[12,"it","like"]
# "Eat24 Food Delivery & Takeout"	[8,"easy","food"]
# "EatStreet Food Delivery App"	[10,"it","order"]
# "Ebates: Cash Back, Coupons, Rewards & Savings"	[8,"ebates","money"]
# "Ebook Reader"	[9,"app","book"]
# "Ecobank Mobile Banking"	[16,"can","t"]
# "Edmodo"	[6,"it","this"]
# "Educational Games 4 Kids"	[7,"games","good"]
# "Educational Games for Kids"	[10,"i","kids"]
# "El tiempo de AEMET"	[3,"a","at"]
# "English with Lingualeo"	[7,"a","not"]
# "English-Myanmar Dictionary"	[5,"button","like"]
# "Entel"	[18,"a","to"]
# "Enterprise Rent-A-Car"	[12,"enterprise","great"]
# "Episode - Choose Your Story"	[23,"fix","like"]
# "Epocrates Plus"	[7,"app","easy"]
# "Equestria Girls"	[30,"but","please"]
# "Essential Anatomy 3"	[28,"full","version"]
# "Essential Resources"	[10,"essential","full"]
# "Etsy: Handmade & Vintage Goods"	[14,"great","s"]
# "Etta Homes"	[7,"easy","love"]
# "Eurosport"	[7,"ad","it"]
# "Eve Period Tracker - Love, Sex & Relationships App"	[6,"app","it"]
# "Even - organize your money, get paid early"	[3,"account","even"]
# "Evernote \u2013 Organizer, Planner for Notes & Memos"	[19,"s","t"]
# "Evie Launcher"	[17,"search","the"]
# "ExDialer - Dialer & Contacts"	[14,"app","call"]
# "Expedia Hotels, Flights & Car Rental Travel Deals"	[16,"app","it"]
# "Expense IQ Money Manager"	[12,"app","update"]
# "Experian - Free Credit Report"	[17,"credit","nan"]
# "Extreme Car Driving Simulator"	[5,"game","it"]
# "Extreme Coupon Finder"	[4,"can","like"]
# "Extreme Match"	[13,"like","love"]
# "Extreme Racing 2 - Real driving RC cars game!"	[14,"game","i"]
# "EyeCloud"	[12,"can","t"]
# "EyeEm - Camera & Photo Filter"	[7,"good","great"]
# "EzCalculator"	[14,"calculator","it"]
# "FBReader: Favorite Book Reader"	[9,"it","reader"]
# "FERZU - Furries Social Network"	[13,"get","the"]
# "FIFA - Tournaments, Soccer News & Live Scores"	[18,"cup","match"]
# "FINAL FANTASY BRAVE EXVIUS"	[10,"playing","s"]
# "FOSSIL Q: DESIGN YOUR DIAL"	[3,"like","t"]
# "FOX NOW - On Demand & Live TV"	[20,"cast","want"]
# "FOX Sports: Live Streaming, Scores & News"	[6,"app","game"]
# "FOX"	[32,"is","the"]
# "FREEDOME VPN Unlimited anonymous Wifi Security"	[2,"easy","fortnite"]
# "FUN Keyboard \u2013 Emoji Keyboard, Sticker,Theme & GIF"	[2,"add","chinese"]
# "Fabulous: Motivate Me! Meditate, Relax, Sleep"	[20,"habits","like"]
# "Face Filter, Selfie Editor - Sweet Camera"	[5,"ads","great"]
# "Facebook Ads Manager"	[7,"ad","app"]
# "Facebook Lite"	[11,"fb","it"]
# "Facebook Local"	[11,"going","it"]
# "Facebook Pages Manager"	[7,"it","notifications"]
# "Facebook"	[34,"posts","time"]
# "Facetune - Ad Free"	[11,"features","like"]
# "Fake Call - Fake Caller ID"	[7,"app","love"]
# "Fallout Shelter"	[13,"fun","good"]
# "Family Album Mitene: Private Photo & Video Sharing"	[9,"great","photos"]
# "Family Dollar"	[10,"coupons","store"]
# "Family GPS Tracker and Chat + Baby Monitor Online"	[9,"good","work"]
# "Family GPS tracker KidControl + GPS by SMS Locator"	[8,"app","great"]
# "Family Locator - GPS Tracker"	[15,"know","phone"]
# "FamilySearch Tree"	[10,"family","nan"]
# "FanDuel: Daily Fantasy Sports"	[5,"games","get"]
# "Fancy Widgets"	[10,"love","widget"]
# "Fandango Movies - Times + Tickets"	[16,"app","easy"]
# "Fantasy Football & NFL News"	[10,"fantasy","players"]
# "Fantasy Football Manager (FPL)"	[6,"app","nan"]
# "Fantasy Football"	[13,"screen","try"]
# "Farm Fruit Pop: Party Time"	[6,"good","it"]
# "Farm Heroes Saga"	[16,"love","please"]
# "Farming Simulator 14"	[8,"good","it"]
# "Farming Simulator 18"	[13,"it","phone"]
# "Fashion in Vogue"	[21,"slow","t"]
# "Fast News"	[25,"i","news"]
# "Fast Scanner : Free PDF Scan"	[14,"pdf","this"]
# "Fast Secure VPN"	[20,"it","vpn"]
# "FastMeet: Chat, Dating, Love"	[6,"accounts","fake"]
# "Fat Burning Workout - Home Weight lose"	[6,"app","phone"]
# "Fate\/Grand Order (English)"	[8,"5","great"]
# "FidMe Loyalty Cards & Deals at Grocery Supermarket"	[5,"code","i"]
# "File Browser by Astro (File Manager)"	[4,"app","need"]
# "File Explorer"	[4,"and","much"]
# "File Manager -- Take Command of Your Files Easily"	[7,"i","it"]
# "File Manager"	[5,"delete","file"]
# "Files Go by Google: Free up space on your phone"	[13,"phone","s"]
# "FilterGrid - Cam&Photo Editor"	[9,"ads","app"]
# "Filters for B Live"	[3,"like","really"]
# "Filters for Selfie"	[5,"bad","filters"]
# "Final Fantasy XV: A New Empire"	[18,"get","the"]
# "Financial Times"	[6,"article","better"]
# "Find Dining Restaurant Finder"	[4,"love","time"]
# "Find a Way: Addictive Puzzle"	[9,"challenging","this"]
# "Find&Save - Local Shopping"	[11,"back","receipt"]
# "FindShip"	[6,"fix","it"]
# "Firefox Browser fast & private"	[17,"chrome","even"]
# "Firefox Focus: The privacy browser"	[22,"new","this"]
# "Fishdom"	[39,"but","play"]
# "Fitbit"	[4,"exercise","fitbit"]
# "Flashlight & LED Torch"	[3,"good","job"]
# "Flashlight - Torch LED Light"	[6,"i","it"]
# "Flashlight HD LED"	[11,"i","nan"]
# "Flashlight"	[5,"it","nice"]
# "Flickr"	[12,"app","auto"]
# "Flight & Hotel Booking App - ixigo"	[8,"good","money"]
# "Flightradar24 Flight Tracker"	[11,"flights","old"]
# "Flights"	[5,"flights","results"]
# "Flip the Gun - Simulator Game"	[11,"ad","many"]
# "FlipaClip - Cartoon animation"	[2,"100","animation"]
# "Flipboard: News For Our Time"	[3,"i","news"]
# "Flipkart Online Shopping App"	[5,"product","products"]
# "Flipp - Weekly Shopping"	[7,"great","list"]
# "Flippy Campus - Buy & sell on campus at a discount"	[6,"good","great"]
# "FlirtChat - \u2665Free Dating\/Flirting App\u2665"	[7,"great","nice"]
# "Floor Plan Creator"	[9,"could","good"]
# "Flow Free"	[52,"puzzles","the"]
# "Flowers Live Wallpaper"	[5,"flowers","i"]
# "Fly Delta"	[18,"great","pass"]
# "FollowMyHealth\u00ae"	[13,"app","doctor"]
# "Font Studio- Photo Texts Image"	[11,"s","the"]
# "Food Calorie Calculator"	[6,"good","t"]
# "Food Network"	[28,"it","tv"]
# "Fooducate Healthy Weight Loss & Calorie Counter"	[6,"foods","it"]
# "Foot Mercato : transferts, r\u00e9sultats, news, live"	[8,"it","to"]
# "Football Live Scores"	[7,"good","it"]
# "ForecaWeather"	[9,"good","location"]
# "Fortune City - A Finance App"	[15,"fun","it"]
# "Four In A Line Free"	[6,"great","it"]
# "Four In A Line"	[10,"10","fun"]
# "Foursquare City Guide"	[5,"area","in"]
# "Foursquare Swarm: Check In"	[11,"check","nan"]
# "Fox Business"	[11,"app","market"]
# "Fox News \u2013 Breaking News, Live Video & News Alerts"	[27,"stories","the"]
# "Fraction Calculator Plus Free"	[5,"app","works"]
# "Free & Premium VPN - FinchVPN"	[8,"it","this"]
# "Free Dating & Flirt Chat - Choice of Love"	[4,"app","like"]
# "Free Dating App & Flirt Chat - Cheers"	[5,"like","ok"]
# "Free Dating App & Flirt Chat - Match with Singles"	[3,"its","nice"]
# "Free Dating App - Meet Local Singles - Flirt Chat"	[12,"profile","time"]
# "Free Dating App - YoCutie - Flirt, Chat & Meet"	[21,"nan","yo"]
# "Free Dating Hook Up Messenger"	[17,"get","using"]
# "Free Foreclosure Real Estate Search by USHUD.com"	[7,"houses","time"]
# "Free Hypnosis"	[5,"a","anxiety"]
# "Free Live Talk-Video Call"	[1,"don","spent"]
# "Free Panda Radio Music"	[2,"it","ok"]
# "Free Sports TV"	[7,"live","watch"]
# "Free TV Shows App:News, TV Series, Episode, Movies"	[10,"free","s"]
# "Free VIN Report for Used Cars"	[10,"app","great"]
# "Free live weather on screen"	[5,"good","love"]
# "Free phone calls, free texting SMS on free number"	[9,"credit","get"]
# "FreePrints \u2013 Free Photos Delivered"	[17,"love","pictures"]
# "Freeletics: Personal Trainer & Fitness Workouts"	[6,"app","free"]
# "Freeme Launcher\u2014Stylish Theme"	[11,"i","launcher"]
# "Fresh EBT - Food Stamp Balance"	[13,"balance","card"]
# "FreshBooks Classic"	[16,"t","the"]
# "Frontback - Social Photos"	[6,"good","it"]
# "Frozen Free Fall"	[10,"let","playing"]
# "Fruit Block - Puzzle Legend"	[2,"1st","from"]
# "Fruit Ninja\u00ae"	[5,"fruit","fun"]
# "Fruits Bomb"	[8,"bread","great"]
# "Fuelio: Gas log & costs"	[12,"easy","nan"]
# "Full Screen Caller ID"	[6,"nice","phone"]
# "Fun Kid Racing - Motocross"	[5,"good","i"]
# "Fun Kid Racing"	[7,"ads","nan"]
# "Funny Alarm Clock Ringtones"	[9,"alarm","it"]
# "Funny Pics"	[6,"community","phone"]
# "Fuzzy Seasons: Animal Forest"	[7,"love","this"]
# "G Cloud Backup"	[10,"backup","cloud"]
# "GANMA! - \u30aa\u30ea\u30b8\u30ca\u30eb\u6f2b\u753b\u304c\u5168\u8a71\u7121\u6599\u3067\u8aad\u307f\u653e\u984c"	[9,"good","manga"]
# "GCash - Buy Load, Pay Bills, Send Money"	[7,"can","nan"]
# "GMAT Math Flashcards"	[8,"flashcards","it"]
# "GMAT Question Bank"	[7,"please","see"]
# "GMX Mail"	[4,"gmx","like"]
# "GO Keyboard - Cute Emojis, Themes and GIFs"	[6,"love","the"]
# "GO Keyboard - Emoticon keyboard, Free Theme, GIF"	[11,"it","keyboard"]
# "GO Notifier"	[18,"notifier","work"]
# "GO SMS Pro - Messenger, Free Themes, Emoji"	[8,"it","the"]
# "GO Weather - Widget, Theme, Wallpaper, Efficient"	[6,"it","the"]
# "GPS Map Free"	[1,"good","just"]
# "GPS Speedometer and Odometer"	[2,"i","works"]
# "GPS Speedometer, Distance Meter"	[6,"it","very"]
# "GPS Status & Toolbox"	[5,"great","it"]
# "GPS Traffic Speedcam Route Planner by ViaMichelin"	[5,"app","car"]
# "GRE Flashcards"	[23,"i","words"]
# "GRE Prep & Practice by Magoosh"	[11,"gre","magoosh"]
# "GRE Tutor"	[8,"word","would"]
# "GS SHOP"	[17,"english","good"]
# "GUNSHIP BATTLE: Helicopter 3D"	[7,"but","connection"]
# "Galactic Core Free Wallpaper"	[11,"get","this"]
# "Galaxy Attack: Alien Shooter"	[25,"games","it"]
# "Game of Thrones: Conquest\u2122"	[4,"i","it"]
# "Gametime - Tickets to Sports, Concerts, Theater"	[9,"easy","love"]
# "Garden Coloring Book"	[12,"color","s"]
# "Garden Fruit Legend"	[10,"i","it"]
# "Garden Photo Frames - Garden Photo Editor"	[7,"good","it"]
# "Gardenscapes"	[52,"levels","the"]
# "Garena Free Fire"	[41,"good","player"]
# "Garmin Connect\u2122"	[9,"app","device"]
# "GasBuddy: Find Cheap Gas"	[13,"it","price"]
# "Gay Sugar Daddy Dating & Hookup \u2013 Sudy Gay"	[16,"good","it"]
# "Gboard - the Google Keyboard"	[24,"google","s"]
# "Gems or jewels ?"	[8,"fun","love"]
# "Genius Scan - PDF Scanner"	[4,"documents","email"]
# "Gmail"	[17,"now","t"]
# "GoBank"	[18,"back","this"]
# "GoPro (formerly Capture)"	[11,"app","can"]
# "Goal Live Scores"	[8,"ads","please"]
# "Goibibo - Flight Hotel Bus Car IRCTC Booking App"	[13,"good","i"]
# "Goku Wallpaper Art"	[5,"best","good"]
# "Gold Butterfly Keyboard Theme"	[7,"good","it"]
# "Golden Dictionary (EN-AR)"	[5,"and","i"]
# "Golden Launcher"	[8,"good","it"]
# "Goldstar: Live Event Tickets"	[7,"i","prices"]
# "Golf Channel"	[9,"load","watch"]
# "Golf GPS Rangefinder: Golf Pad"	[9,"golf","watch"]
# "Golf GPS by SwingxSwing"	[13,"it","round"]
# "GolfLogix GPS + Putt Breaks"	[9,"app","time"]
# "GolfNow: Tee Time Deals at Golf Courses, Golf GPS"	[13,"course","get"]
# "Golfshot Plus: Golf GPS"	[9,"app","great"]
# "Golfshot: Golf GPS + Tee Times"	[16,"app","golf"]
# "GoodRx Drug Prices and Coupons"	[13,"insurance","it"]
# "Google Ads"	[14,"business","it"]
# "Google Duo - High Quality Video Calls"	[6,"calls","google"]
# "Google Earth"	[12,"like","s"]
# "Google Fit - Fitness Tracking"	[9,"phone","wear"]
# "Google Handwriting Input"	[5,"android","app"]
# "Google Keep"	[36,"keep","like"]
# "Google My Business"	[12,"s","very"]
# "Google News"	[56,"it","this"]
# "Google PDF Viewer"	[18,"file","page"]
# "Google Pay"	[36,"it","this"]
# "Google Photos"	[51,"phone","s"]
# "Google Primer"	[1,"good","great"]
# "Google Slides"	[1,"great","greatest"]
# "Google Street View"	[3,"is","my"]
# "Google Translate"	[3,"english","idiom"]
# "Google Voice"	[3,"app","it"]
# "Google"	[12,"assistant","can"]
# "Google+"	[1,"according","ads"]
# "Granny"	[18,"granny","this"]
# "Graphing Calculator"	[18,"graphing","it"]
# "Grim Soul: Dark Fantasy Survival"	[16,"it","like"]
# "Groovebook Photo Books & Gifts"	[18,"love","pics"]
# "GroupMe"	[15,"app","like"]
# "Groupon - Shop Deals, Discounts & Coupons"	[27,"deals","good"]
# "Grubhub: Food Delivery"	[10,"2","delivered"]
# "Guns of Glory"	[7,"money","the"]
# "Gyft - Mobile Gift Card Wallet"	[27,"great","used"]
# "H Pack"	[28,"not","the"]
# "H TV"	[6,"i","tv"]
# "H&M"	[14,"app","it"]
# "HBO GO: Stream with TV Package"	[9,"app","s"]
# "HD Camera - Best Cam with filters & panorama"	[2,"awesome","camera"]
# "HD Camera - Quick Snap Photo & Video"	[4,"good","it"]
# "HD Camera Pro for Android"	[3,"good","great"]
# "HD Camera Ultra"	[6,"ads","app"]
# "HD Camera for Android"	[12,"camera","good"]
# "HD Camera"	[1,"camera","error"]
# "HD Movie Video Player"	[15,"ads","it"]
# "HD Video Player"	[13,"i","it"]
# "HD Widgets"	[9,"nan","t"]
# "HDFC Bank MobileBanking"	[17,"it","new"]
# "HESI A2 Pocket Prep"	[7,"app","questions"]
# "HISTORY: Watch TV Show Full Episodes & Specials"	[26,"it","shows"]
# "HTC Calendar"	[2,"htc","slow"]
# "HTC File Manager"	[5,"otg","storage"]
# "HTC Gallery"	[10,"can","phone"]
# "HTC Help"	[10,"help","update"]
# "HTC Lock Screen"	[6,"m8","this"]
# "HTC Mail"	[18,"htc","mail"]
# "HTC Sense Input"	[19,"htc","keyboard"]
# "HTC Sense Input-AR"	[9,"good","it"]
# "HTC Service \uff0d DLNA"	[10,"messed","t"]
# "HTC Service\u2014Video Player"	[17,"play","player"]
# "HTC Social Plugin - Facebook"	[16,"it","phone"]
# "HTC Speak"	[8,"t","voice"]
# "HTC Weather"	[8,"city","time"]
# "Hacker's Keyboard"	[17,"this","would"]
# "Hairstyles step by step"	[19,"good","it"]
# "Hamilton \u2014 The Official App"	[11,"karaoke","would"]
# "Hangouts"	[18,"phone","this"]
# "Happify"	[2,"it","s"]
# "Happy Birthday Songs Offline"	[4,"easy","nice"]
# "Happy Fruits Bomb - Cube Blast"	[5,"fun","love"]
# "Happy Street"	[6,"back","could"]
# "Harkins Theatres"	[4,"get","this"]
# "Harry Potter: Hogwarts Mystery"	[23,"make","would"]
# "HauteLook"	[5,"app","great"]
# "Hay Day"	[17,"s","the"]
# "Haystack TV: Local & World News - Free"	[4,"it","news"]
# "Headspace: Meditation & Mindfulness"	[5,"10","it"]
# "Health and Nutrition Guide"	[10,"app","s"]
# "HealtheLife"	[6,"name","time"]
# "Healthy Recipes Free"	[5,"easy","great"]
# "Helix Jump"	[79,"free","s"]
# "Hello Kitty Lunchbox"	[8,"hello","love"]
# "Hello Kitty Nail Salon"	[16,"every","get"]
# "Hello Stars"	[10,"fun","good"]
# "HelloTalk \u2014 Chat, Speak & Learn Foreign Languages"	[2,"can","if"]
# "Hero Hunters"	[10,"nan","still"]
# "Herpes Dating: 1,000K+ Singles"	[12,"it","like"]
# "Herpes Positive Singles Dating"	[6,"app","it"]
# "Hide App, Private Dating, Safe Chat - PrivacyHider"	[17,"it","please"]
# "Hide Something - Photo, Video"	[7,"m","s"]
# "Hideman VPN"	[5,"loading","this"]
# "High Blood Pressure Symptoms"	[9,"app","it"]
# "High-Powered Flashlight"	[6,"nan","very"]
# "High-Speed Camera (GIF,Burst)"	[3,"better","like"]
# "Hill Climb Racing 2"	[15,"it","play"]
# "Hill Climb Racing"	[12,"back","love"]
# "Hily: Dating, Chat, Match, Meet & Hook up"	[18,"nan","never"]
# "Hinge: Dating & Relationships"	[15,"dating","even"]
# "HipChat - Chat Built for Teams"	[13,"chat","notifications"]
# "Hipmunk Hotels & Flights"	[5,"flight","nan"]
# "Hitwe - meet people and chat"	[4,"fake","many"]
# "Hole19: Golf GPS App, Rangefinder & Scorecard"	[4,"can","easy"]
# "Home Decor Showpiece Art making: Medium Difficulty"	[4,"good","nice"]
# "Home Scouting\u00ae MLS Mobile"	[6,"great","waste"]
# "Home Security Camera WardenCam - reuse old phones"	[9,"great","it"]
# "Home Street \u2013 Home Design Game"	[14,"like","really"]
# "Home Workout - No Equipment"	[11,"app","great"]
# "Home Workout for Men - Bodybuilding"	[4,"exercise","really"]
# "Home workouts - fat burning, abs, legs, arms,chest"	[5,"exercises","great"]
# "HomeWork"	[1,"homework","its"]
# "Homes.com \ud83c\udfe0 For Sale, Rent"	[3,"easy","it"]
# "Homescapes"	[28,"nan","the"]
# "Homesnap Real Estate & Rentals"	[10,"app","great"]
# "Homestyler Interior Design & Decorating Ideas"	[12,"design","like"]
# "Homework Planner"	[15,"it","would"]
# "Honkai Impact 3rd"	[36,"like","really"]
# "Hopper - Watch & Book Flights"	[28,"flights","wait"]
# "Horoscopes \u2013 Daily Zodiac Horoscope and Astrology"	[5,"horoscope","nan"]
# "Horses Live Wallpaper"	[7,"love","nan"]
# "Hostelworld: Hostels & Cheap Hotels Travel App"	[15,"great","nan"]
# "Hot Wheels: Race Off"	[6,"cars","good"]
# "HotelTonight: Book amazing deals at great hotels"	[23,"deals","good"]
# "Hotels Combined - Cheap deals"	[5,"booking","hotel"]
# "Hotels.com: Book Hotel Rooms & Find Vacation Deals"	[16,"app","find"]
# "Hotspot Shield Free VPN Proxy & Wi-Fi Security"	[3,"it","trial"]
# "Hotstar"	[13,"answer","shows"]
# "Hotwire Hotel & Car Rental App"	[7,"nan","would"]
# "Housing-Real Estate & Property"	[6,"posted","waste"]
